# %%
import os
import gc
import sys
import glob
import numpy as np
import pandas as pd
import netCDF4 as nc
from datetime import datetime, timedelta
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as mticker

# %%
file_name = "/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process3_output/curves/raw_data_Qle_VPD_hourly_RM16_DT_EF_model_0.8-1.0.csv"

# %%
f_in      = pd.read_csv(file_name,usecols=['obs_SWdown','model_NASAEnt'])

# %%
f_in
# 'model_CABLE', 'model_CABLE-POP-CN', 'model_CHTESSEL_Ref_exp1','model_CLM5a', 'model_GFDL', 'model_JULES_GL9', 'model_JULES_GL9_withLAI',
# 'model_MATSIRO', 'model_MuSICA', 'model_NASAEnt', 'model_NoahMPv401', 'model_ORC2_r6593',  'model_ORC3_r8120', 'model_QUINCY', '
# 'model_STEMMUS-SCOPE', 'obs', 'obs_cor',
# Out:
#          model_NASAEnt  obs_SWdown
# 0                  NaN      56.738
# 1                  NaN      60.676
# 2                  NaN     166.278
# 3                  NaN     276.072
# 4                  NaN     387.147
# ...                ...         ...
# 8133181            NaN     329.133
# 8133182            NaN     133.263
# 8133183            NaN      79.010
# 8133184            NaN      42.987
# 8133185            NaN      14.243
#
# [8133186 rows x 2 columns]

# %%
plt.scatter(f_in['obs_SWdown'],f_in['model_NASAEnt'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')

# %%
f_in      = pd.read_csv(file_name,usecols=['obs_SWdown','model_CABLE'])

# %%
plt.scatter(f_in['obs_SWdown'],f_in['model_CABLE'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')

# %%
f_in      = pd.read_csv(file_name,usecols=['obs_SWdown','model_QUINCY'])

# %%
plt.scatter(f_in['obs_SWdown'],f_in['model_QUINCY'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')

# %%
file_name = "/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process3_output/curves/raw_data_Qle_VPD_hourly_RM16_DT_EF_model_0-0.2.csv"

# %%
f_in      = pd.read_csv(file_name,usecols=['obs_SWdown','model_NASAEnt'])

# %%
plt.scatter(f_in['obs_SWdown'],f_in['model_NASAEnt'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
