# %%
import os
import gc
import sys
import glob
import numpy as np
import pandas as pd
import netCDF4 as nc
from datetime import datetime, timedelta
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as mticker
from copy import deepcopy
from scipy.stats import percentileofscore

# %%
# To use PLUMBER2_GPP_common_utils, change directory to where it exists
os.chdir('/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2')
from PLUMBER2_VPD_common_utils import *

# %%
file_SM_per = '/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process3_output/curves/raw_data_Qle_VPD_hourly_RM16_DT_SM_per_all_models_0-15th.csv'
SM_per      = pd.read_csv(file_SM_per)

# %%
# for clim in clim_all:
clim_mask        = (SM_per['climate_type']=='Aw') | (SM_per['climate_type']=='Am') | (SM_per['climate_type']=='Af')
var_new          = SM_per[clim_mask]
plt.scatter(var_new['VPD'],var_new['obs_SWdown'],s=0.5,alpha=0.05,c='blue',label='Am')
plt.xlim(0, 8)
plt.show()

# %%
# for clim in clim_all:
clim_mask        = (SM_per['climate_type']=='BSh') | (SM_per['climate_type']=='BSk') | \
                   (SM_per['climate_type']=='BWh') | (SM_per['climate_type']=='BWk')
var_new          = SM_per[clim_mask]
plt.scatter(var_new['VPD'],var_new['obs_SWdown'],s=0.5,alpha=0.05,c='red',label='BSk')
plt.xlim(0,8)
plt.show()

# %%
# for clim in clim_all:
clim_mask        = (SM_per['climate_type']=='Cfa') | (SM_per['climate_type']=='Cfb')| \
                   (SM_per['climate_type']=='Csa') | (SM_per['climate_type']=='Csb')
var_new          = SM_per[clim_mask]
plt.scatter(var_new['VPD'],var_new['obs_SWdown'],s=0.5,alpha=0.05,c='orange',label='Cfa')
plt.xlim(0,8)
plt.show()

# %%
# for clim in clim_all:
clim_mask        = (SM_per['climate_type']=='Dfa') | (SM_per['climate_type']=='Dfb') \
                   | (SM_per['climate_type']=='Dfc') | (SM_per['climate_type']=='Dsc') \
                   | (SM_per['climate_type']=='Dwa') | (SM_per['climate_type']=='Dwb')
var_new          = SM_per[clim_mask]
plt.scatter(var_new['VPD'],var_new['obs_SWdown'],s=0.5,alpha=0.05,c='green',label='Dfa')
plt.xlim(0,8)
plt.show()

# %%
plt.show()
