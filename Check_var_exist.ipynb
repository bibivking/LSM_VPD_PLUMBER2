# %%
import os
import gc
import sys
import glob
import numpy as np
import pandas as pd
import netCDF4 as nc
from datetime import datetime, timedelta
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as mticker

# %%
# To use PLUMBER2_GPP_common_utils, change directory to where it exists
os.chdir('/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2')
from PLUMBER2_VPD_common_utils import *

# %%
# Path of PLUMBER 2 dataset
PLUMBER2_path      = "/g/data/w97/mm3972/data/PLUMBER2/"
PLUMBER2_flux_path = "/g/data/w97/mm3972/data/Fluxnet_data/Post-processed_PLUMBER2_outputs/Nc_files/Flux/"
PLUMBER2_met_path  = "/g/data/w97/mm3972/data/Fluxnet_data/Post-processed_PLUMBER2_outputs/Nc_files/Met/"


model_names   = ['CABLE', 'CABLE-POP-CN',
                 'CHTESSEL_Ref_exp1', 'CLM5a', 'GFDL',
                 'JULES_GL9', 'JULES_GL9_withLAI',
                 'MATSIRO', 'MuSICA', 'NASAEnt',
                 'NoahMPv401', 'ORC2_r6593',
                 'ORC3_r8120', 'QUINCY',
                 'STEMMUS-SCOPE']#, 'obs'] #"BEPS"

all_site_path  = sorted(glob.glob(PLUMBER2_met_path+"/*.nc"))
site_names     = [os.path.basename(site_path).split("_")[0] for site_path in all_site_path]

# %%
varname       = "Rnet"
for site_name in site_names:
    trans_dict    = check_variable_exists(PLUMBER2_path, varname, site_name, model_names)
    print(site_name,trans_dict)
# Out:
# Rnet
# AR-SLu {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AT-Neu {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-ASM {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Cow {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Cpr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Ctr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Cum {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-DaP {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-DaS {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Dry {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Emr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-GWW {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Gin {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-How {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Lit {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Otw {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Rig {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, AU-Rob, ORC2_r6593, []
# An error occurred: list index out of range, AU-Rob, ORC2_r6593, []
# An error occurred: list index out of range, AU-Rob, ORC2_r6593, []
# An error occurred: list index out of range, AU-Rob, ORC2_r6593, []
# An error occurred: list index out of range, AU-Rob, ORC2_r6593, []
# An error occurred: list index out of range, AU-Rob, ORC2_r6593, []
# An error occurred: list index out of range, AU-Rob, ORC3_r8120, []
# An error occurred: list index out of range, AU-Rob, ORC3_r8120, []
# An error occurred: list index out of range, AU-Rob, ORC3_r8120, []
# An error occurred: list index out of range, AU-Rob, ORC3_r8120, []
# An error occurred: list index out of range, AU-Rob, ORC3_r8120, []
# An error occurred: list index out of range, AU-Rob, ORC3_r8120, []
# AU-Rob {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': 'None', 'ORC3_r8120': 'None', 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Sam {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Stp {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-TTE {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Tum {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# AU-Whr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, AU-Wrr, ORC2_r6593, []
# An error occurred: list index out of range, AU-Wrr, ORC2_r6593, []
# An error occurred: list index out of range, AU-Wrr, ORC2_r6593, []
# An error occurred: list index out of range, AU-Wrr, ORC2_r6593, []
# An error occurred: list index out of range, AU-Wrr, ORC2_r6593, []
# An error occurred: list index out of range, AU-Wrr, ORC2_r6593, []
# An error occurred: list index out of range, AU-Wrr, ORC3_r8120, []
# An error occurred: list index out of range, AU-Wrr, ORC3_r8120, []
# An error occurred: list index out of range, AU-Wrr, ORC3_r8120, []
# An error occurred: list index out of range, AU-Wrr, ORC3_r8120, []
# An error occurred: list index out of range, AU-Wrr, ORC3_r8120, []
# An error occurred: list index out of range, AU-Wrr, ORC3_r8120, []
# AU-Wrr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': 'None', 'ORC3_r8120': 'None', 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, AU-Ync, QUINCY, []
# An error occurred: list index out of range, AU-Ync, QUINCY, []
# An error occurred: list index out of range, AU-Ync, QUINCY, []
# An error occurred: list index out of range, AU-Ync, QUINCY, []
# An error occurred: list index out of range, AU-Ync, QUINCY, []
# An error occurred: list index out of range, AU-Ync, QUINCY, []
# AU-Ync {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'None', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# BE-Bra {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# BE-Lon {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# BE-Vie {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# BR-Sa3 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# BW-Ma1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-NS1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, CA-NS2, ORC2_r6593, []
# An error occurred: list index out of range, CA-NS2, ORC2_r6593, []
# An error occurred: list index out of range, CA-NS2, ORC2_r6593, []
# An error occurred: list index out of range, CA-NS2, ORC2_r6593, []
# An error occurred: list index out of range, CA-NS2, ORC2_r6593, []
# An error occurred: list index out of range, CA-NS2, ORC2_r6593, []
# An error occurred: list index out of range, CA-NS2, ORC3_r8120, []
# An error occurred: list index out of range, CA-NS2, ORC3_r8120, []
# An error occurred: list index out of range, CA-NS2, ORC3_r8120, []
# An error occurred: list index out of range, CA-NS2, ORC3_r8120, []
# An error occurred: list index out of range, CA-NS2, ORC3_r8120, []
# An error occurred: list index out of range, CA-NS2, ORC3_r8120, []
# CA-NS2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': 'None', 'ORC3_r8120': 'None', 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-NS4 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-NS5 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, CA-NS6, MuSICA, []
# An error occurred: list index out of range, CA-NS6, MuSICA, []
# An error occurred: list index out of range, CA-NS6, MuSICA, []
# An error occurred: list index out of range, CA-NS6, MuSICA, []
# An error occurred: list index out of range, CA-NS6, MuSICA, []
# An error occurred: list index out of range, CA-NS6, MuSICA, []
# CA-NS6 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': 'None', 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, CA-NS7, MuSICA, []
# An error occurred: list index out of range, CA-NS7, MuSICA, []
# An error occurred: list index out of range, CA-NS7, MuSICA, []
# An error occurred: list index out of range, CA-NS7, MuSICA, []
# An error occurred: list index out of range, CA-NS7, MuSICA, []
# An error occurred: list index out of range, CA-NS7, MuSICA, []
# CA-NS7 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': 'None', 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-Qcu {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-Qfo {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-SF1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-SF2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CA-SF3 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CH-Cha {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CH-Dav {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CH-Fru {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CH-Oe1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CN-Cha {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CN-Cng {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CN-Dan {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, CN-Din, ORC2_r6593, []
# An error occurred: list index out of range, CN-Din, ORC2_r6593, []
# An error occurred: list index out of range, CN-Din, ORC2_r6593, []
# An error occurred: list index out of range, CN-Din, ORC2_r6593, []
# An error occurred: list index out of range, CN-Din, ORC2_r6593, []
# An error occurred: list index out of range, CN-Din, ORC2_r6593, []
# An error occurred: list index out of range, CN-Din, ORC3_r8120, []
# An error occurred: list index out of range, CN-Din, ORC3_r8120, []
# An error occurred: list index out of range, CN-Din, ORC3_r8120, []
# An error occurred: list index out of range, CN-Din, ORC3_r8120, []
# An error occurred: list index out of range, CN-Din, ORC3_r8120, []
# An error occurred: list index out of range, CN-Din, ORC3_r8120, []
# CN-Din {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': 'None', 'ORC3_r8120': 'None', 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CN-Du2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CN-HaM {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CN-Qia {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# CZ-wet {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Bay {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Geb {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Gri {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Hai {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Kli {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Meh {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Obe {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Seh {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-SfN {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Tha {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DE-Wet {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DK-Fou {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DK-Lva {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DK-Ris {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DK-Sor {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# DK-ZaH {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ES-ES1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ES-ES2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ES-LMa {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ES-LgS {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ES-VDA {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FI-Hyy {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FI-Kaa {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FI-Lom {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FI-Sod {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FR-Fon {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FR-Gri {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FR-Hes {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FR-LBr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FR-Lq1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FR-Lq2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# FR-Pue {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# GF-Guy {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# HU-Bug {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ID-Pag {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IE-Ca1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IE-Dri {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Amp {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-BCi {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-CA1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-CA2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-CA3 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Col {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Cpz {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Isp {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-LMa {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Lav {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-MBo {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Mal {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Noe {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# IT-Non {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ...
# Rnet
# US-GLE {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Goo {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Ha1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Ho1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-KS2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Los {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-MMS {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-MOz {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Me2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Me4 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Me6 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Myb {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-NR1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Ne1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Ne2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Ne3 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-PFa {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Prr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-SP1 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-SP2 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-SP3 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-SRG {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-SRM {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Syv {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Ton {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Tw4 {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Twt {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-UMB {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Var {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, US-WCr, ORC2_r6593, []
# An error occurred: list index out of range, US-WCr, ORC2_r6593, []
# An error occurred: list index out of range, US-WCr, ORC2_r6593, []
# An error occurred: list index out of range, US-WCr, ORC2_r6593, []
# An error occurred: list index out of range, US-WCr, ORC2_r6593, []
# An error occurred: list index out of range, US-WCr, ORC2_r6593, []
# An error occurred: list index out of range, US-WCr, ORC3_r8120, []
# An error occurred: list index out of range, US-WCr, ORC3_r8120, []
# An error occurred: list index out of range, US-WCr, ORC3_r8120, []
# An error occurred: list index out of range, US-WCr, ORC3_r8120, []
# An error occurred: list index out of range, US-WCr, ORC3_r8120, []
# An error occurred: list index out of range, US-WCr, ORC3_r8120, []
# US-WCr {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': 'None', 'ORC3_r8120': 'None', 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Whs {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# US-Wkg {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# ZA-Kru {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': ['SWnet', 'LWnet'], 'ORC3_r8120': ['SWnet', 'LWnet'], 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
# Rnet
# An error occurred: list index out of range, ZM-Mon, ORC2_r6593, []
# An error occurred: list index out of range, ZM-Mon, ORC2_r6593, []
# An error occurred: list index out of range, ZM-Mon, ORC2_r6593, []
# An error occurred: list index out of range, ZM-Mon, ORC2_r6593, []
# An error occurred: list index out of range, ZM-Mon, ORC2_r6593, []
# An error occurred: list index out of range, ZM-Mon, ORC2_r6593, []
# An error occurred: list index out of range, ZM-Mon, ORC3_r8120, []
# An error occurred: list index out of range, ZM-Mon, ORC3_r8120, []
# An error occurred: list index out of range, ZM-Mon, ORC3_r8120, []
# An error occurred: list index out of range, ZM-Mon, ORC3_r8120, []
# An error occurred: list index out of range, ZM-Mon, ORC3_r8120, []
# An error occurred: list index out of range, ZM-Mon, ORC3_r8120, []
# ZM-Mon {'CABLE': 'Rnet', 'CABLE-POP-CN': 'Rnet', 'CHTESSEL_Ref_exp1': ['Qle', 'Qh', 'Qg'], 'CLM5a': 'Rnet', 'GFDL': 'Rnet', 'JULES_GL9': ['Qle', 'Qh', 'None'], 'JULES_GL9_withLAI': 'Rnet', 'MATSIRO': 'Rnet', 'MuSICA': ['SWnet', 'LWnet'], 'NASAEnt': ['SWnet', 'LWnet'], 'NoahMPv401': ['SWnet', 'LWnet'], 'ORC2_r6593': 'None', 'ORC3_r8120': 'None', 'QUINCY': 'Rnet', 'STEMMUS-SCOPE': 'Rnet'}
