# %%
import os
import gc
import sys
import glob
import numpy as np
import pandas as pd
import netCDF4 as nc
from datetime import datetime, timedelta
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as mticker

# %%
# half_hrs_after_precip,obs_LAI,ORC2_r6593_LAI,ORC2_r6593_CO2_LAI,ORC3_r7245_NEE_LAI,ORC3_r8120_LAI,GFDL_LAI,SDGVM_LAI,QUINCY_LAI,NoahMPv401_LAI
plt.scatter(var_output['obs_LAI'],var_output['ORC2_r6593_CO2_LAI'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(-1,10),np.arange(-1,10),c='black')

# %%
# half_hrs_after_precip,obs_LAI,ORC2_r6593_LAI,ORC2_r6593_CO2_LAI,ORC3_r7245_NEE_LAI,ORC3_r8120_LAI,GFDL_LAI,SDGVM_LAI,QUINCY_LAI,NoahMPv401_LAI
plt.scatter(var_output['obs_LAI'],var_output['ORC3_r7245_NEE_LAI'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(-1,10),np.arange(-1,10),c='black')

# %%
# half_hrs_after_precip,obs_LAI,ORC2_r6593_LAI,ORC2_r6593_CO2_LAI,ORC3_r7245_NEE_LAI,ORC3_r8120_LAI,GFDL_LAI,SDGVM_LAI,QUINCY_LAI,NoahMPv401_LAI
plt.scatter(var_output['obs_LAI'],var_output['ORC3_r8120_LAI'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(-1,10),np.arange(-1,10),c='black')

# %%
# half_hrs_after_precip,obs_LAI,ORC2_r6593_LAI,ORC2_r6593_CO2_LAI,ORC3_r7245_NEE_LAI,ORC3_r8120_LAI,GFDL_LAI,SDGVM_LAI,QUINCY_LAI,NoahMPv401_LAI
plt.scatter(var_output['obs_LAI'],var_output['GFDL_LAI'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(-1,10),np.arange(-1,10),c='black')

# %%
# half_hrs_after_precip,obs_LAI,ORC2_r6593_LAI,ORC2_r6593_CO2_LAI,ORC3_r7245_NEE_LAI,ORC3_r8120_LAI,GFDL_LAI,SDGVM_LAI,QUINCY_LAI,NoahMPv401_LAI
plt.scatter(var_output['obs_LAI'],var_output['SDGVM_LAI'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(-1,10),np.arange(-1,10),c='black')

# %%
# half_hrs_after_precip,obs_LAI,ORC2_r6593_LAI,ORC2_r6593_CO2_LAI,ORC3_r7245_NEE_LAI,ORC3_r8120_LAI,GFDL_LAI,SDGVM_LAI,QUINCY_LAI,NoahMPv401_LAI
plt.scatter(var_output['obs_LAI'],var_output['QUINCY_LAI'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(-1,10),np.arange(-1,10),c='black')

# %%
# half_hrs_after_precip,obs_LAI,ORC2_r6593_LAI,ORC2_r6593_CO2_LAI,ORC3_r7245_NEE_LAI,ORC3_r8120_LAI,GFDL_LAI,SDGVM_LAI,QUINCY_LAI,NoahMPv401_LAI
plt.scatter(var_output['obs_LAI'],var_output['NoahMPv401_LAI'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(-1,10),np.arange(-1,10),c='black')

# %%
var_output   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process2_output/daily/Gs_all_sites_daily.csv",
                           na_values=[''],usecols=["model_CABLE","CABLE_VPDl","obs","obs_VPDl","model_CABLE-POP-CN","CABLE-POP-CN_VPDl"])
plt.scatter(var_output['obs'],var_output['model_CABLE'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(0,5),np.arange(0,5),c='black')

# %%
plt.scatter(var_output['model_CABLE-POP-CN'],var_output['model_CABLE'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
plt.plot(np.arange(0,5),np.arange(0,5),c='black')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.scatter(var_output['model_CABLE-POP-CN'],var_output['model_CABLE'], s=0.5, facecolors='none', edgecolors='blue',  alpha=0.5, label='data points')
#       2 plt.plot(np.arange(0,5),np.arange(0,5),c='black')
#
# NameError: name 'var_output' is not defined

# %% [markdown]
# ## GAM parameter set 1: lam = np.logspace(-5, 5, 11); n_splines = np.arange(3, 10, 1)

# %%
Qle_GAM_02   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/CRV_fit_GAM_complex/Qle_hourly_RM16_DT_EF_model_0-0.2_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_04   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/CRV_fit_GAM_complex/Qle_hourly_RM16_DT_EF_model_0.2-0.4_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_06   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/CRV_fit_GAM_complex/Qle_hourly_RM16_DT_EF_model_0.4-0.6_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_08   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/CRV_fit_GAM_complex/Qle_hourly_RM16_DT_EF_model_0.6-0.8_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_10   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/CRV_fit_GAM_complex/Qle_hourly_RM16_DT_EF_model_0.8-1.0_CRV_fit_GAM_complex.csv", na_values=[''])

# %%
model_colors = {
                'obs': 'black',
                'CABLE':'darkblue',
                'CABLE-POP-CN':'blue',
                'CHTESSEL_ERA5_3':'cornflowerblue',
                'CHTESSEL_Ref_exp1':'c',
                'CLM5a':'deepskyblue',
                'GFDL':'aquamarine',
                'JULES_GL9_withLAI':'lime',
                'JULES_test':'forestgreen',
                'LPJ-GUESS':'darkolivegreen',
                'MATSIRO':'limegreen',
                'MuSICA':'yellowgreen',
                'NASAEnt':'yellow'  ,
                'NoahMPv401':'gold',
                'ORC2_r6593':'orange',
                'ORC2_r6593_CO2':'red',
                'ORC3_r7245_NEE':'coral',
                'ORC3_r8120':'pink',
                'QUINCY':'deeppink',
                'SDGVM':'violet' ,
                'STEMMUS-SCOPE':'darkviolet' ,
                }

# %%
model_list        = ['CABLE', 'CABLE-POP-CN', 'CHTESSEL_ERA5_3',
                     'CHTESSEL_Ref_exp1', 'CLM5a', 'GFDL',
                     'JULES_GL9_withLAI', 'JULES_test',
                     'MATSIRO', 'MuSICA', 'NASAEnt',
                     'NoahMPv401', 'ORC2_r6593', 'ORC2_r6593_CO2',
                     'ORC3_r7245_NEE', 'ORC3_r8120', 'QUINCY',
                     'STEMMUS-SCOPE', 'obs']

# %%
vpd_top      = 7.05 #7.04
vpd_bot      = 0.1 #0.02
vpd_interval = 0.1 #0.04

var_vpd_series = np.arange(vpd_bot,vpd_top,vpd_interval)

for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_02[model_out_name+'_vals']
    vals_bot   = Qle_GAM_02[model_out_name+'_bot']
    vals_top   = Qle_GAM_02[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_04[model_out_name+'_vals']
    vals_bot   = Qle_GAM_04[model_out_name+'_bot']
    vals_top   = Qle_GAM_04[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_06[model_out_name+'_vals']
    vals_bot   = Qle_GAM_06[model_out_name+'_bot']
    vals_top   = Qle_GAM_06[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_08[model_out_name+'_vals']
    vals_bot   = Qle_GAM_08[model_out_name+'_bot']
    vals_top   = Qle_GAM_08[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_10[model_out_name+'_vals']
    vals_bot   = Qle_GAM_10[model_out_name+'_bot']
    vals_top   = Qle_GAM_10[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %% [markdown]
# ## GAM parameter set 2: lam = np.logspace(-3, 3, 11); n_splines = np.arange(3, 5, 1)

# %%
Qle_GAM_02   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0-0.2_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_04   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.2-0.4_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_06   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.4-0.6_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_08   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.6-0.8_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_10   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.8-1.0_CRV_fit_GAM_complex.csv", na_values=[''])

# %%
vpd_top      = 7.05 #7.04
vpd_bot      = 0.1 #0.02
vpd_interval = 0.1 #0.04

var_vpd_series = np.arange(vpd_bot,vpd_top,vpd_interval)

for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_02[model_out_name+'_vals']
    vals_bot   = Qle_GAM_02[model_out_name+'_bot']
    vals_top   = Qle_GAM_02[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_04[model_out_name+'_vals']
    vals_bot   = Qle_GAM_04[model_out_name+'_bot']
    vals_top   = Qle_GAM_04[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_06[model_out_name+'_vals']
    vals_bot   = Qle_GAM_06[model_out_name+'_bot']
    vals_top   = Qle_GAM_06[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_08[model_out_name+'_vals']
    vals_bot   = Qle_GAM_08[model_out_name+'_bot']
    vals_top   = Qle_GAM_08[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_10[model_out_name+'_vals']
    vals_bot   = Qle_GAM_10[model_out_name+'_bot']
    vals_top   = Qle_GAM_10[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
Qle_GAM_02   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0-0.2_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_04   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.2-0.4_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_06   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.4-0.6_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_08   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.6-0.8_CRV_fit_GAM_complex.csv", na_values=[''])
Qle_GAM_10   = pd.read_csv("/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process4_output/original_clarify_site/Qle_hourly_RM16_DT_EF_model_0.8-1.0_CRV_fit_GAM_complex.csv", na_values=[''])

# %%
vpd_top      = 7.05 #7.04
vpd_bot      = 0.1 #0.02
vpd_interval = 0.1 #0.04

var_vpd_series = np.arange(vpd_bot,vpd_top,vpd_interval)

for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_02[model_out_name+'_vals']
    vals_bot   = Qle_GAM_02[model_out_name+'_bot']
    vals_top   = Qle_GAM_02[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_04[model_out_name+'_vals']
    vals_bot   = Qle_GAM_04[model_out_name+'_bot']
    vals_top   = Qle_GAM_04[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_06[model_out_name+'_vals']
    vals_bot   = Qle_GAM_06[model_out_name+'_bot']
    vals_top   = Qle_GAM_06[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_08[model_out_name+'_vals']
    vals_bot   = Qle_GAM_08[model_out_name+'_bot']
    vals_top   = Qle_GAM_08[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()

# %%
for model_out_name in model_list:
    
    # set line color
    line_color = model_colors[model_out_name]
    
    value      = Qle_GAM_10[model_out_name+'_vals']
    vals_bot   = Qle_GAM_10[model_out_name+'_bot']
    vals_top   = Qle_GAM_10[model_out_name+'_top']
    
    # print(var_vpd_series,value,vals_bot,vals_top)
    plt.plot(var_vpd_series, value, lw=1, color=line_color, alpha=0.8, label=model_out_name) #edgecolor='none', c='red' .rolling(window=10).mean()
    plt.fill_between(var_vpd_series,vals_bot.values,vals_top.values, color=line_color, edgecolor="none", alpha=0.2) #  .rolling(window=10).mean()
plt.show()
