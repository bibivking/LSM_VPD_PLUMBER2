# %%
import os
import gc
import sys
import glob
import numpy as np
import pandas as pd
import netCDF4 as nc
from datetime import datetime, timedelta
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as mticker
from copy import deepcopy
from scipy.stats import percentileofscore

# %%
# To use PLUMBER2_GPP_common_utils, change directory to where it exists
os.chdir('/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2')
from PLUMBER2_VPD_common_utils import *

# %%
# Read quality contral file
file_name1 = "/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process1_output/Qle_all_sites.csv" 
file_name2 = "/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process2_output/data_selection_all_sites.csv" 
Qle_input  = pd.read_csv(file_name1)
data_selection_input = pd.read_csv(file_name2)

# %%
site_names, IGBP_types, clim_types, model_names = load_default_list()
for site_name in site_names:
    site_mask = (data_selection_input['site_name']==site_name)
    print(site_name, np.sum(data_selection_input.loc[site_mask, 'select_data']))
# Out:
# AR-SLu 4797
# AT-Neu 10671
# AU-ASM 31081
# AU-Cow 12219
# AU-Cpr 33798
# AU-Ctr 16568
# AU-Cum 19291
# AU-DaP 15741
# AU-DaS 33970
# AU-Dry 20918
# AU-Emr 10547
# AU-GWW 17816
# AU-Gin 26340
# AU-How 51142
# AU-Lit 7797
# AU-Otw 1732
# AU-Rig 0
# AU-Rob 0
# AU-Sam 20424
# AU-Stp 38956
# AU-TTE 22705
# AU-Tum 16852
# AU-Whr 0
# AU-Wrr 0
# AU-Ync 0
# BE-Bra 28178
# BE-Lon 20659
# BE-Vie 35643
# BR-Sa3 9201
# BW-Ma1 5859
# CA-NS1 0
# CA-NS2 0
# CA-NS4 0
# CA-NS5 0
# CA-NS6 0
# CA-NS7 0
# CA-Qcu 5685
# CA-Qfo 9511
# CA-SF1 0
# CA-SF2 0
# CA-SF3 0
# CH-Cha 9060
# CH-Dav 22922
# CH-Fru 11139
# CH-Oe1 10803
# CN-Cha 4019
# CN-Cng 5186
# CN-Dan 1346
# CN-Din 0
# CN-Du2 3549
# CN-HaM 622
# CN-Qia 7159
# CZ-wet 10179
# DE-Bay 4621
# DE-Geb 27073
# DE-Gri 16124
# DE-Hai 21219
# DE-Kli 19578
# DE-Meh 6370
# DE-Obe 14664
# DE-Seh 5679
# DE-SfN 2273
# DE-Tha 38311
# DE-Wet 9908
# DK-Fou 969
# DK-Lva 4562
# DK-Ris 3504
# DK-Sor 40423
# DK-ZaH 1127
# ES-ES1 41383
# ES-ES2 8391
# ES-LMa 13019
# ES-LgS 2072
# ES-VDA 2228
# FI-Hyy 35298
# FI-Kaa 4043
# FI-Lom 2752
# FI-Sod 10896
# FR-Fon 22860
# FR-Gri 21475
# FR-Hes 18018
# FR-LBr 16910
# FR-Lq1 6086
# FR-Lq2 6291
# FR-Pue 52322
# GF-Guy 22035
# HU-Bug 8795
# ID-Pag 6094
# IE-Ca1 5138
# IE-Dri 4721
# IT-Amp 3861
# IT-BCi 18757
# IT-CA1 5172
# IT-CA2 6471
# IT-CA3 6188
# IT-Col 15684
# IT-Cpz 22783
# IT-Isp 2377
# IT-LMa 1901
# IT-Lav 12542
# IT-MBo 16309
# IT-Mal 1596
# IT-Noe 41514
# IT-Non 1408
# IT-PT1 3616
# IT-Ren 6260
# IT-Ro1 17734
# IT-Ro2 20753
# IT-SR2 5737
# IT-SRo 30941
# JP-SMF 11790
# NL-Ca1 9447
# NL-Hor 2771
# NL-Loo 36380
# PL-wet 3591
# PT-Esp 10818
# PT-Mi1 4653
# PT-Mi2 6851
# RU-Che 0
# RU-Fyo 18558
# RU-Zot 0
# SD-Dem 16743
# SE-Deg 4595
# UK-Gri 2359
# UK-Ham 1958
# UK-PL3 0
# US-AR1 9889
# US-AR2 7314
# US-ARM 35750
# US-Aud 11874
# US-Bar 1258
# US-Bkg 3704
# US-Blo 27570
# US-Bo1 25927
# US-Cop 3583
# US-FPe 11749
# US-GLE 9946
# US-Goo 8608
# US-Ha1 12832
# US-Ho1 16708
# US-KS2 15443
# US-Los 12476
# US-MMS 14181
# US-MOz 6064
# US-Me2 40184
# US-Me4 1405
# US-Me6 6641
# US-Myb 17920
# US-NR1 26361
# US-Ne1 8598
# US-Ne2 8126
# US-Ne3 9208
# US-PFa 12016
# US-Prr 4586
# US-SP1 0
# US-SP2 16211
# US-SP3 17017
# US-SRG 29375
# US-SRM 57378
# US-Syv 9539
# US-Ton 69991
# US-Tw4 4600
# US-Twt 17979
# US-UMB 11318
# US-Var 58684
# US-WCr 0
# US-Whs 35674
# US-Wkg 55579
# ZA-Kru 10907
# ZM-Mon 0

# %%
site_names, IGBP_types, clim_types, model_names = load_default_list()
model_names = ['model_CABLE', 'model_CABLE-POP-CN', 'model_CHTESSEL_Ref_exp1', 'model_CLM5a', 'model_GFDL',
               'model_JULES_GL9', 'model_JULES_GL9_withLAI', 'model_MATSIRO', 'model_MuSICA', 'model_NASAEnt',
               'model_NoahMPv401', 'model_ORC2_r6593', 'model_ORC3_r8120', 'model_QUINCY', 'model_STEMMUS-SCOPE','obs']
for site_name in site_names:
    file_name3     = f"/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/txt/process3_output/curves/raw_data_Qle_VPD_hourly_SM_per_all_models_0-15th_data_selected_{site_name}.csv"
    process3_input = pd.read_csv(file_name3)
    
    for model_name in model_names:
        tmp = pd.to_numeric(process3_input[model_name], errors='coerce')
        if np.sum(~np.isnan(tmp)) > 0:  
            # print(site_name,model_name,np.unique(process3_input[model_name]))
            print(site_name,model_name,np.sum(~np.isnan(tmp)))
# Out:
# AT-Neu model_CABLE 3340
# AT-Neu model_CABLE-POP-CN 3340
# AT-Neu model_CHTESSEL_Ref_exp1 2808
# AT-Neu model_CLM5a 2763
# AT-Neu model_GFDL 2893
# AT-Neu model_JULES_GL9 2840
# AT-Neu model_JULES_GL9_withLAI 2845
# AT-Neu model_MATSIRO 3530
# AT-Neu model_MuSICA 3013
# AT-Neu model_NASAEnt 3158
# AT-Neu model_NoahMPv401 2953
# AT-Neu model_ORC2_r6593 3308
# AT-Neu model_ORC3_r8120 3272
# AT-Neu model_QUINCY 3158
# AT-Neu model_STEMMUS-SCOPE 3124
# AT-Neu obs 3158
# AU-Ctr model_CABLE 4385
# AU-Ctr model_CABLE-POP-CN 4385
# AU-Ctr model_CHTESSEL_Ref_exp1 4224
# AU-Ctr model_CLM5a 3530
# AU-Ctr model_GFDL 3812
# AU-Ctr model_JULES_GL9 4095
# AU-Ctr model_JULES_GL9_withLAI 3948
# AU-Ctr model_MATSIRO 3749
# AU-Ctr model_MuSICA 3937
# AU-Ctr model_NASAEnt 4116
# AU-Ctr model_NoahMPv401 4547
# AU-Ctr model_ORC2_r6593 4312
# AU-Ctr model_ORC3_r8120 4394
# AU-Ctr model_QUINCY 4116
# AU-Ctr model_STEMMUS-SCOPE 3992
# AU-Ctr obs 4116
# AU-DaP model_CABLE 3122
# AU-DaP model_CABLE-POP-CN 3122
# AU-DaP model_CHTESSEL_Ref_exp1 3017
# AU-DaP model_CLM5a 3598
# AU-DaP model_GFDL 3815
# AU-DaP model_JULES_GL9 3101
# AU-DaP model_JULES_GL9_withLAI 3152
# AU-DaP model_MATSIRO 3646
# AU-DaP model_MuSICA 2812
# AU-DaP model_NASAEnt 3134
# AU-DaP model_NoahMPv401 3118
# AU-DaP model_ORC2_r6593 3346
# AU-DaP model_ORC3_r8120 3078
# AU-DaP model_QUINCY 3134
# AU-DaP model_STEMMUS-SCOPE 3120
# AU-DaP obs 3134
# BE-Vie model_CABLE 12320
# BE-Vie model_CABLE-POP-CN 12014
# BE-Vie model_CHTESSEL_Ref_exp1 10928
# BE-Vie model_CLM5a 11713
# BE-Vie model_GFDL 9070
# BE-Vie model_JULES_GL9 11325
# BE-Vie model_JULES_GL9_withLAI 11326
# BE-Vie model_MATSIRO 9236
# BE-Vie model_MuSICA 10884
# BE-Vie model_NASAEnt 11191
# BE-Vie model_NoahMPv401 11627
# BE-Vie model_ORC2_r6593 12119
# BE-Vie model_ORC3_r8120 12468
# BE-Vie model_QUINCY 11191
# BE-Vie model_STEMMUS-SCOPE 9888
# BE-Vie obs 11191
# CH-Oe1 model_CABLE 4152
# CH-Oe1 model_CABLE-POP-CN 4152
# CH-Oe1 model_CHTESSEL_Ref_exp1 3839
# CH-Oe1 model_CLM5a 4084
# CH-Oe1 model_GFDL 3668
# CH-Oe1 model_JULES_GL9 3738
# CH-Oe1 model_JULES_GL9_withLAI 3750
# CH-Oe1 model_MATSIRO 3256
# CH-Oe1 model_MuSICA 3869
# CH-Oe1 model_NASAEnt 3969
# CH-Oe1 model_NoahMPv401 4128
# CH-Oe1 model_ORC2_r6593 3927
# CH-Oe1 model_ORC3_r8120 4083
# CH-Oe1 model_QUINCY 3969
# CH-Oe1 model_STEMMUS-SCOPE 3757
# CH-Oe1 obs 3969
# CN-Dan model_CABLE 198
# CN-Dan model_CABLE-POP-CN 198
# CN-Dan model_CHTESSEL_Ref_exp1 277
# CN-Dan model_CLM5a 333
# CN-Dan model_GFDL 253
# CN-Dan model_JULES_GL9 207
# CN-Dan model_JULES_GL9_withLAI 209
# CN-Dan model_MATSIRO 353
# CN-Dan model_MuSICA 86
# CN-Dan model_NASAEnt 304
# CN-Dan model_NoahMPv401 183
# CN-Dan model_ORC2_r6593 212
# CN-Dan model_ORC3_r8120 398
# CN-Dan model_QUINCY 304
# CN-Dan model_STEMMUS-SCOPE 255
# CN-Dan obs 304
# DE-Gri model_CABLE 5497
# DE-Gri model_CABLE-POP-CN 5497
# DE-Gri model_CHTESSEL_Ref_exp1 5292
# DE-Gri model_CLM5a 5247
# DE-Gri model_GFDL 5187
# DE-Gri model_JULES_GL9 5164
# DE-Gri model_JULES_GL9_withLAI 5089
# DE-Gri model_MATSIRO 4536
# DE-Gri model_MuSICA 5204
# DE-Gri model_NASAEnt 5381
# DE-Gri model_NoahMPv401 5626
# DE-Gri model_ORC2_r6593 5279
# DE-Gri model_ORC3_r8120 5497
# DE-Gri model_QUINCY 5381
# DE-Gri model_STEMMUS-SCOPE 4792
# DE-Gri obs 5381
# ES-ES1 model_CABLE 8996
# ES-ES1 model_CABLE-POP-CN 8996
# ES-ES1 model_CHTESSEL_Ref_exp1 8429
# ES-ES1 model_CLM5a 8670
# ES-ES1 model_GFDL 8936
# ES-ES1 model_JULES_GL9 8299
# ES-ES1 model_JULES_GL9_withLAI 8104
# ES-ES1 model_MATSIRO 8349
# ES-ES1 model_MuSICA 8009
# ES-ES1 model_NASAEnt 8679
# ES-ES1 model_NoahMPv401 8426
# ES-ES1 model_ORC2_r6593 8928
# ES-ES1 model_ORC3_r8120 8909
# ES-ES1 model_QUINCY 8679
# ES-ES1 model_STEMMUS-SCOPE 7996
# ES-ES1 obs 8679
# ES-ES2 model_CABLE 1917
# ES-ES2 model_CABLE-POP-CN 1917
# ES-ES2 model_CHTESSEL_Ref_exp1 1800
# ES-ES2 model_CLM5a 1797
# ES-ES2 model_GFDL 1792
# ES-ES2 model_JULES_GL9 1756
# ES-ES2 model_JULES_GL9_withLAI 1687
# ES-ES2 model_MATSIRO 1878
# ES-ES2 model_MuSICA 1946
# ES-ES2 model_NASAEnt 1883
# ES-ES2 model_NoahMPv401 1728
# ES-ES2 model_ORC2_r6593 2043
# ES-ES2 model_ORC3_r8120 1966
# ES-ES2 model_QUINCY 1883
# ES-ES2 model_STEMMUS-SCOPE 1848
# ES-ES2 obs 1883
# FI-Lom model_CABLE 1202
# FI-Lom model_CABLE-POP-CN 1202
# FI-Lom model_CHTESSEL_Ref_exp1 692
# FI-Lom model_CLM5a 1409
# FI-Lom model_GFDL 1295
# FI-Lom model_JULES_GL9 1082
# FI-Lom model_JULES_GL9_withLAI 1112
# FI-Lom model_MATSIRO 1061
# FI-Lom model_MuSICA 944
# FI-Lom model_NASAEnt 1272
# FI-Lom model_NoahMPv401 941
# FI-Lom model_ORC2_r6593 1308
# FI-Lom model_ORC3_r8120 1294
# FI-Lom model_QUINCY 1272
# FI-Lom model_STEMMUS-SCOPE 1381
# FI-Lom obs 1272
# FR-LBr model_CABLE 4788
# FR-LBr model_CABLE-POP-CN 4788
# FR-LBr model_CHTESSEL_Ref_exp1 4664
# FR-LBr model_CLM5a 4491
# FR-LBr model_GFDL 4597
# FR-LBr model_JULES_GL9 4286
# FR-LBr model_JULES_GL9_withLAI 3993
# FR-LBr model_MATSIRO 3673
# FR-LBr model_MuSICA 4331
# FR-LBr model_NASAEnt 4447
# FR-LBr model_NoahMPv401 4508
# FR-LBr model_ORC2_r6593 5001
# FR-LBr model_ORC3_r8120 4954
# FR-LBr model_QUINCY 4447
# FR-LBr model_STEMMUS-SCOPE 4574
# FR-LBr obs 4447
# FR-Pue model_CABLE 14560
# FR-Pue model_CABLE-POP-CN 14560
# FR-Pue model_CHTESSEL_Ref_exp1 13747
# FR-Pue model_CLM5a 13699
# FR-Pue model_GFDL 14805
# FR-Pue model_JULES_GL9 13596
# FR-Pue model_JULES_GL9_withLAI 13578
# FR-Pue model_MATSIRO 13559
# FR-Pue model_MuSICA 13455
# FR-Pue model_NASAEnt 14043
# FR-Pue model_NoahMPv401 13716
# FR-Pue model_ORC2_r6593 14191
# FR-Pue model_ORC3_r8120 14614
# FR-Pue model_QUINCY 14043
# FR-Pue model_STEMMUS-SCOPE 14002
# FR-Pue obs 14043
# IE-Dri model_CABLE 1771
# IE-Dri model_CABLE-POP-CN 1771
# IE-Dri model_CHTESSEL_Ref_exp1 1575
# IE-Dri model_CLM5a 1662
# IE-Dri model_GFDL 1487
# IE-Dri model_JULES_GL9 1594
# IE-Dri model_JULES_GL9_withLAI 1597
# IE-Dri model_MATSIRO 1564
# IE-Dri model_MuSICA 1682
# IE-Dri model_NASAEnt 1653
# IE-Dri model_NoahMPv401 1687
# IE-Dri model_ORC2_r6593 1834
# IE-Dri model_ORC3_r8120 1711
# IE-Dri model_QUINCY 1653
# IE-Dri model_STEMMUS-SCOPE 1499
# IE-Dri obs 1653
# IT-Amp model_CABLE 1741
# IT-Amp model_CABLE-POP-CN 1741
# IT-Amp model_CHTESSEL_Ref_exp1 1447
# IT-Amp model_CLM5a 1356
# IT-Amp model_GFDL 1675
# IT-Amp model_JULES_GL9 1519
# IT-Amp model_JULES_GL9_withLAI 1501
# IT-Amp model_MATSIRO 1577
# IT-Amp model_MuSICA 1208
# IT-Amp model_NASAEnt 1483
# IT-Amp model_NoahMPv401 1344
# IT-Amp model_ORC2_r6593 1888
# IT-Amp model_ORC3_r8120 1818
# IT-Amp model_QUINCY 1483
# IT-Amp model_STEMMUS-SCOPE 1556
# IT-Amp obs 1483
# IT-BCi model_CABLE 5283
# IT-BCi model_CABLE-POP-CN 5283
# IT-BCi model_CHTESSEL_Ref_exp1 5012
# IT-BCi model_CLM5a 6063
# IT-BCi model_GFDL 5332
# IT-BCi model_JULES_GL9 5062
# IT-BCi model_JULES_GL9_withLAI 5050
# IT-BCi model_MATSIRO 4664
# IT-BCi model_MuSICA 4970
# IT-BCi model_NASAEnt 5068
# IT-BCi model_NoahMPv401 4954
# IT-BCi model_ORC2_r6593 5388
# IT-BCi model_ORC3_r8120 5309
# IT-BCi model_QUINCY 5068
# IT-BCi model_STEMMUS-SCOPE 5097
# IT-BCi obs 5068
# IT-Isp model_CABLE 600
# IT-Isp model_CABLE-POP-CN 600
# IT-Isp model_CHTESSEL_Ref_exp1 665
# IT-Isp model_CLM5a 634
# IT-Isp model_GFDL 705
# IT-Isp model_JULES_GL9 635
# IT-Isp model_JULES_GL9_withLAI 592
# IT-Isp model_MATSIRO 649
# IT-Isp model_MuSICA 492
# IT-Isp model_NASAEnt 642
# IT-Isp model_NoahMPv401 640
# IT-Isp model_ORC2_r6593 553
# IT-Isp model_ORC3_r8120 539
# IT-Isp model_QUINCY 642
# IT-Isp model_STEMMUS-SCOPE 577
# IT-Isp obs 642
# IT-Ro1 model_CABLE 4908
# IT-Ro1 model_CABLE-POP-CN 4908
# IT-Ro1 model_CHTESSEL_Ref_exp1 4575
# IT-Ro1 model_CLM5a 4606
# IT-Ro1 model_GFDL 4972
# IT-Ro1 model_JULES_GL9 4377
# IT-Ro1 model_JULES_GL9_withLAI 4395
# IT-Ro1 model_MATSIRO 4035
# IT-Ro1 model_MuSICA 4486
# IT-Ro1 model_NASAEnt 4690
# IT-Ro1 model_NoahMPv401 4515
# IT-Ro1 model_ORC2_r6593 4860
# IT-Ro1 model_ORC3_r8120 4813
# IT-Ro1 model_QUINCY 4690
# IT-Ro1 model_STEMMUS-SCOPE 4591
# IT-Ro1 obs 4690
# IT-Ro2 model_CABLE 5809
# IT-Ro2 model_CABLE-POP-CN 5809
# IT-Ro2 model_CHTESSEL_Ref_exp1 5269
# IT-Ro2 model_CLM5a 5418
# IT-Ro2 model_GFDL 5828
# IT-Ro2 model_JULES_GL9 5345
# IT-Ro2 model_JULES_GL9_withLAI 5244
# IT-Ro2 model_MATSIRO 5030
# IT-Ro2 model_MuSICA 5269
# IT-Ro2 model_NASAEnt 5493
# IT-Ro2 model_NoahMPv401 5369
# IT-Ro2 model_ORC2_r6593 5708
# IT-Ro2 model_ORC3_r8120 5624
# IT-Ro2 model_QUINCY 5493
# IT-Ro2 model_STEMMUS-SCOPE 5367
# IT-Ro2 obs 5493
# PT-Mi1 model_CABLE 812
# PT-Mi1 model_CABLE-POP-CN 812
# PT-Mi1 model_CHTESSEL_Ref_exp1 812
# PT-Mi1 model_CLM5a 843
# PT-Mi1 model_GFDL 1147
# PT-Mi1 model_JULES_GL9 812
# PT-Mi1 model_JULES_GL9_withLAI 812
# PT-Mi1 model_MATSIRO 839
# PT-Mi1 model_MuSICA 812
# PT-Mi1 model_NASAEnt 812
# PT-Mi1 model_NoahMPv401 812
# PT-Mi1 model_ORC2_r6593 861
# PT-Mi1 model_ORC3_r8120 858
# PT-Mi1 model_QUINCY 812
# PT-Mi1 model_STEMMUS-SCOPE 835
# PT-Mi1 obs 812
# US-AR1 model_CABLE 2450
# US-AR1 model_CABLE-POP-CN 2350
# US-AR1 model_CHTESSEL_Ref_exp1 2372
# US-AR1 model_CLM5a 2292
# US-AR1 model_GFDL 2121
# US-AR1 model_JULES_GL9 2512
# US-AR1 model_JULES_GL9_withLAI 2271
# US-AR1 model_MATSIRO 2382
# US-AR1 model_MuSICA 2287
# US-AR1 model_NASAEnt 2270
# US-AR1 model_NoahMPv401 2172
# US-AR1 model_ORC2_r6593 2043
# US-AR1 model_ORC3_r8120 2207
# US-AR1 model_QUINCY 2270
# US-AR1 model_STEMMUS-SCOPE 2351
# US-AR1 obs 2270
# US-Me2 model_CABLE 12299
# US-Me2 model_CABLE-POP-CN 12299
# US-Me2 model_CHTESSEL_Ref_exp1 11512
# US-Me2 model_CLM5a 9835
# US-Me2 model_GFDL 11283
# US-Me2 model_JULES_GL9 10465
# US-Me2 model_JULES_GL9_withLAI 10332
# US-Me2 model_MATSIRO 10493
# US-Me2 model_MuSICA 11690
# US-Me2 model_NASAEnt 11414
# US-Me2 model_NoahMPv401 11612
# US-Me2 model_ORC2_r6593 12640
# US-Me2 model_ORC3_r8120 12740
# US-Me2 model_QUINCY 11414
# US-Me2 model_STEMMUS-SCOPE 11632
# US-Me2 obs 11414
# US-Ne2 model_CABLE 1820
# US-Ne2 model_CABLE-POP-CN 1820
# US-Ne2 model_CHTESSEL_Ref_exp1 1805
# US-Ne2 model_CLM5a 3486
# US-Ne2 model_GFDL 2095
# US-Ne2 model_JULES_GL9 1687
# US-Ne2 model_JULES_GL9_withLAI 1594
# US-Ne2 model_MATSIRO 2135
# US-Ne2 model_MuSICA 1108
# US-Ne2 model_NASAEnt 2049
# US-Ne2 model_NoahMPv401 1792
# US-Ne2 model_ORC2_r6593 1189
# US-Ne2 model_ORC3_r8120 1461
# US-Ne2 model_QUINCY 2050
# US-Ne2 model_STEMMUS-SCOPE 2405
# US-Ne2 obs 2050
# US-PFa model_CABLE 4806
# US-PFa model_CABLE-POP-CN 4581
# US-PFa model_CHTESSEL_Ref_exp1 4104
# US-PFa model_CLM5a 4501
# US-PFa model_GFDL 4517
# US-PFa model_JULES_GL9 4120
# US-PFa model_JULES_GL9_withLAI 3940
# US-PFa model_MATSIRO 3466
# US-PFa model_MuSICA 4209
# US-PFa model_NASAEnt 4614
# US-PFa model_NoahMPv401 4149
# US-PFa model_ORC2_r6593 3038
# US-PFa model_ORC3_r8120 3102
# US-PFa model_QUINCY 4614
# US-PFa model_STEMMUS-SCOPE 90
# US-PFa obs 4614
# US-SRG model_CABLE 5849
# US-SRG model_CABLE-POP-CN 5849
# US-SRG model_CHTESSEL_Ref_exp1 6068
# US-SRG model_CLM5a 6032
# US-SRG model_GFDL 6189
# US-SRG model_JULES_GL9 6328
# US-SRG model_JULES_GL9_withLAI 5290
# US-SRG model_MATSIRO 5902
# US-SRG model_MuSICA 5136
# US-SRG model_NASAEnt 5905
# US-SRG model_NoahMPv401 6043
# US-SRG model_ORC2_r6593 4835
# US-SRG model_ORC3_r8120 6293
# US-SRG model_QUINCY 5905
# US-SRG model_STEMMUS-SCOPE 5597
# US-SRG obs 5905
# US-Ton model_CABLE 13836
# US-Ton model_CABLE-POP-CN 12360
# US-Ton model_CHTESSEL_Ref_exp1 11958
# US-Ton model_CLM5a 12833
# US-Ton model_GFDL 16643
# US-Ton model_JULES_GL9 11788
# US-Ton model_JULES_GL9_withLAI 11652
# US-Ton model_MATSIRO 13521
# US-Ton model_MuSICA 12033
# US-Ton model_NASAEnt 12443
# US-Ton model_NoahMPv401 11831
# US-Ton model_ORC2_r6593 13838
# US-Ton model_ORC3_r8120 14429
# US-Ton model_QUINCY 12443
# US-Ton model_STEMMUS-SCOPE 14224
# US-Ton obs 12443
# ZA-Kru model_CABLE 2594
# ZA-Kru model_CABLE-POP-CN 2524
# ZA-Kru model_CHTESSEL_Ref_exp1 2534
# ZA-Kru model_CLM5a 2522
# ZA-Kru model_GFDL 2316
# ZA-Kru model_JULES_GL9 2500
# ZA-Kru model_JULES_GL9_withLAI 2289
# ZA-Kru model_MATSIRO 2495
# ZA-Kru model_MuSICA 2478
# ZA-Kru model_NASAEnt 2575
# ZA-Kru model_NoahMPv401 2512
# ZA-Kru model_ORC2_r6593 2571
# ZA-Kru model_ORC3_r8120 2568
# ZA-Kru model_QUINCY 2575
# ZA-Kru model_STEMMUS-SCOPE 2492
# ZA-Kru obs 2575

# %%
add_SMtopXm='0.3'
low_bound  = [0,15]
high_bound = [85,100]

'''
Be carefull: this script select the time steps that all 13 models with SM simulations are within the
required ranges, rather than the models with the variable (such as TVeg, non TVeg have fewer models).
That's the reason use model_names rather than model_out_list
'''

for site_name in site_names:
    site_mask = (data_selection_input['site_name']==site_name)
    all_mask = (site_mask) & (data_selection_input['select_data'])

    tmp_input = Qle_input[all_mask]
    var_output_dry = copy.deepcopy(tmp_input)
    var_output_wet = copy.deepcopy(tmp_input)

    print(site_name,len(var_output_dry))
# # select time step where obs_EF isn't NaN (when Qh<0 or Qle+Qh<10)
# for i, model_out_name in enumerate(model_names):
#     if 'obs' in model_out_name:
#         head = ''
#     else:
#         head = 'model_'
#     SM_per_name = model_out_name+'_SMtop'+str(add_SMtopXm)+'m_percentile'

#     if len(low_bound)>1 and len(high_bound)>1:
#         dry_mask  = (var_output[SM_per_name] > low_bound[0]) & (var_output[SM_per_name] < low_bound[1])
#         wet_mask  = (var_output[SM_per_name] > high_bound[0]) & (var_output[SM_per_name] < high_bound[1])
#     elif len(low_bound)==1 and len(high_bound)==1:
#         dry_mask  = (var_output[SM_per_name] < low_bound)
#         wet_mask  = (var_output[SM_per_name] > high_bound)
#     else:
#         sys.exit('len(low_bound)=',len(low_bound),'len(high_bound)=',len(high_bound))

#     var_output_dry[head+model_out_name] = np.where(dry_mask, var_output[head+model_out_name], np.nan)
#     var_output_wet[head+model_out_name] = np.where(wet_mask, var_output[head+model_out_name], np.nan)

# SM_per_model_names = ['CABLE_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'CABLE-POP-CN_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'CHTESSEL_Ref_exp1_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'CLM5a_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'GFDL_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'JULES_GL9_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'JULES_GL9_withLAI_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'MATSIRO_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'MuSICA_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'NoahMPv401_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'ORC2_r6593_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'ORC3_r8120_SMtop'+str(add_SMtopXm)+'m_percentile',
#                       'STEMMUS-SCOPE_SMtop'+str(add_SMtopXm)+'m_percentile']

# # Print the expected column names
# print("Expected columns (SM_per_model_names):")
# print(SM_per_model_names)

# # Print the actual columns in the DataFrame
# print("Columns in var_output_dry:")
# print(var_output_dry.columns)
# # return

# # Mask out SM is inconsistent
# var_output_dry[SM_per_model_names] = var_output_dry[SM_per_model_names].where(~var_output_dry[SM_per_model_names].isna().any(axis=1), other=np.nan)
# var_output_wet[SM_per_model_names] = var_output_wet[SM_per_model_names].where(~var_output_wet[SM_per_model_names].isna().any(axis=1), other=np.nan)

# for model_out_name in model_out_list:
#     if 'obs' in model_out_name:
#         head = ''
#     else:
#         head = 'model_'
#     var_output_dry.loc[:,head+model_out_name] = np.where(~np.isnan(var_output_dry['CABLE_SMtop'+str(add_SMtopXm)+'m_percentile'].values),
#                                                    var_output_dry[head+model_out_name], np.nan)
#     var_output_wet.loc[:,head+model_out_name] = np.where(~np.isnan(var_output_wet['CABLE_SMtop'+str(add_SMtopXm)+'m_percentile'].values),
#                                                    var_output_wet[head+model_out_name], np.nan)
# Out:
# AR-SLu 4797
# AT-Neu 10671
# AU-ASM 31081
# AU-Cow 12219
# AU-Cpr 33798
# AU-Ctr 16568
# AU-Cum 19291
# AU-DaP 15741
# AU-DaS 33970
# AU-Dry 20918
# AU-Emr 10547
# AU-GWW 17816
# AU-Gin 26340
# AU-How 51142
# AU-Lit 7797
# AU-Otw 1732
# AU-Rig 0
# AU-Rob 0
# AU-Sam 20424
# AU-Stp 38956
# AU-TTE 22705
# AU-Tum 16852
# AU-Whr 0
# AU-Wrr 0
# AU-Ync 0
# BE-Bra 28178
# BE-Lon 20659
# BE-Vie 35643
# BR-Sa3 9201
# BW-Ma1 5859
# CA-NS1 0
# CA-NS2 0
# CA-NS4 0
# CA-NS5 0
# CA-NS6 0
# CA-NS7 0
# CA-Qcu 5685
# CA-Qfo 9511
# CA-SF1 0
# CA-SF2 0
# CA-SF3 0
# CH-Cha 9060
# CH-Dav 22922
# CH-Fru 11139
# CH-Oe1 10803
# CN-Cha 4019
# CN-Cng 5186
# CN-Dan 1346
# CN-Din 0
# CN-Du2 3549
# CN-HaM 622
# CN-Qia 7159
# CZ-wet 10179
# DE-Bay 4621
# DE-Geb 27073
# DE-Gri 16124
# DE-Hai 21219
# DE-Kli 19578
# DE-Meh 6370
# DE-Obe 14664
# DE-Seh 5679
# DE-SfN 2273
# DE-Tha 38311
# DE-Wet 9908
# DK-Fou 969
# DK-Lva 4562
# DK-Ris 3504
# DK-Sor 40423
# DK-ZaH 1127
# ES-ES1 41383
# ES-ES2 8391
# ES-LMa 13019
# ES-LgS 2072
# ES-VDA 2228
# FI-Hyy 35298
# FI-Kaa 4043
# FI-Lom 2752
# FI-Sod 10896
# FR-Fon 22860
# FR-Gri 21475
# FR-Hes 18018
# FR-LBr 16910
# FR-Lq1 6086
# FR-Lq2 6291
# FR-Pue 52322
# GF-Guy 22035
# HU-Bug 8795
# ID-Pag 6094
# IE-Ca1 5138
# IE-Dri 4721
# IT-Amp 3861
# IT-BCi 18757
# IT-CA1 5172
# IT-CA2 6471
# IT-CA3 6188
# IT-Col 15684
# IT-Cpz 22783
# IT-Isp 2377
# IT-LMa 1901
# IT-Lav 12542
# IT-MBo 16309
# IT-Mal 1596
# IT-Noe 41514
# IT-Non 1408
# IT-PT1 3616
# IT-Ren 6260
# IT-Ro1 17734
# IT-Ro2 20753
# IT-SR2 5737
# IT-SRo 30941
# JP-SMF 11790
# NL-Ca1 9447
# NL-Hor 2771
# NL-Loo 36380
# PL-wet 3591
# PT-Esp 10818
# PT-Mi1 4653
# PT-Mi2 6851
# RU-Che 0
# RU-Fyo 18558
# RU-Zot 0
# SD-Dem 16743
# SE-Deg 4595
# UK-Gri 2359
# UK-Ham 1958
# UK-PL3 0
# US-AR1 9889
# US-AR2 7314
# US-ARM 35750
# US-Aud 11874
# US-Bar 1258
# US-Bkg 3704
# US-Blo 27570
# US-Bo1 25927
# US-Cop 3583
# US-FPe 11749
# US-GLE 9946
# US-Goo 8608
# US-Ha1 12832
# US-Ho1 16708
# US-KS2 15443
# US-Los 12476
# US-MMS 14181
# US-MOz 6064
# US-Me2 40184
# US-Me4 1405
# US-Me6 6641
# US-Myb 17920
# US-NR1 26361
# US-Ne1 8598
# US-Ne2 8126
# US-Ne3 9208
# US-PFa 12016
# US-Prr 4586
# US-SP1 0
# US-SP2 16211
# US-SP3 17017
# US-SRG 29375
# US-SRM 57378
# US-Syv 9539
# US-Ton 69991
# US-Tw4 4600
# US-Twt 17979
# US-UMB 11318
# US-Var 58684
# US-WCr 0
# US-Whs 35674
# US-Wkg 55579
# ZA-Kru 10907
# ZM-Mon 0
