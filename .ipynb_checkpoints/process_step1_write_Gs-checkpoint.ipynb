# %%
import os
import sys
import gc
import glob
import numpy as np
import pandas as pd
import netCDF4 as nc
from datetime import datetime, timedelta
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as mticker
# from PLUMBER2_VPD_common_utils import *

# %%
PLUMBER2_met_path   = "/g/data/w97/mm3972/data/Fluxnet_data/Post-processed_PLUMBER2_outputs/Nc_files/Met/"
PLUMBER2_path       = "/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2/nc_files/"
PLUMBER2_path_input = "/g/data/w97/mm3972/data/PLUMBER2/"
PLUMBER2_script     = "/g/data/w97/mm3972/scripts/PLUMBER2/LSM_VPD_PLUMBER2"
country_code        = ''
all_site_path       = sorted(glob.glob(PLUMBER2_path+"/*"+country_code+"*.nc"))
site_names          = [os.path.basename(site_path).split(".")[0] for site_path in all_site_path]

model_names         = ['CABLE', 'CABLE-POP-CN', 'CHTESSEL_ERA5_3',
                         'CHTESSEL_Ref_exp1', 'CLM5a', 'GFDL',
                         'JULES_GL9_withLAI', 'JULES_test',
                         'MATSIRO', 'MuSICA', 'NASAEnt',
                         'NoahMPv401', 'ORC2_r6593', 'ORC2_r6593_CO2',
                         'ORC3_r7245_NEE', 'ORC3_r8120', 'QUINCY',
                         'STEMMUS-SCOPE', 'obs']

# %%
# def write_gs_to_spatial_land_days(PLUMBER2_script, site_names, model_names,filter=False):

"""Parallelized version of the function."""

var_input = pd.read_csv(f'{PLUMBER2_script}/txt/process1_output/Qle_all_sites.csv', na_values=[''], usecols=[
     'time', 'CABLE_EF', 'CABLE-POP-CN_EF', 'CHTESSEL_ERA5_3_EF', 'CHTESSEL_Ref_exp1_EF', 
     'CLM5a_EF', 'GFDL_EF', 'JULES_GL9_withLAI_EF', 'JULES_test_EF', 'MATSIRO_EF', 'MuSICA_EF', 
     'NASAEnt_EF', 'NoahMPv401_EF', 'ORC2_r6593_EF', 'ORC2_r6593_CO2_EF', 'ORC3_r7245_NEE_EF', 
     'ORC3_r8120_EF', 'QUINCY_EF', 'STEMMUS-SCOPE_EF', 'obs_EF', 'VPD', 'obs_Tair', 'obs_Qair',
     'obs_Precip','NoahMPv401_greenness','month','hour','site_name','IGBP_type','climate_type',
     'half_hrs_after_precip'])

# %%
for model_in in model_names:
    if model_in == 'obs':
        header = ''
    else:
        header = 'model_'
    var_input[header+model_in]  = np.nan
    var_input[model_in+'_VPDl'] = np.nan

# %%
print(var_input.columns)
# Out:
# Index(['time', 'CABLE_EF', 'CABLE-POP-CN_EF', 'CHTESSEL_ERA5_3_EF',
#        'CHTESSEL_Ref_exp1_EF', 'CLM5a_EF', 'GFDL_EF', 'JULES_GL9_withLAI_EF',
#        'JULES_test_EF', 'MATSIRO_EF', 'MuSICA_EF', 'NASAEnt_EF',
#        'NoahMPv401_EF', 'ORC2_r6593_EF', 'ORC2_r6593_CO2_EF',
#        'ORC3_r7245_NEE_EF', 'ORC3_r8120_EF', 'QUINCY_EF', 'STEMMUS-SCOPE_EF',
#        'obs_EF', 'VPD', 'obs_Tair', 'obs_Qair', 'obs_Precip',
#        'NoahMPv401_greenness', 'month', 'hour', 'site_name', 'IGBP_type',
#        'climate_type', 'half_hrs_after_precip', 'model_CABLE', 'CABLE_VPDl',
#        'model_CABLE-POP-CN', 'CABLE-POP-CN_VPDl', 'model_CHTESSEL_ERA5_3',
#        'CHTESSEL_ERA5_3_VPDl', 'model_CHTESSEL_Ref_exp1',
#        'CHTESSEL_Ref_exp1_VPDl', 'model_CLM5a', 'CLM5a_VPDl', 'model_GFDL',
#        'GFDL_VPDl', 'model_JULES_GL9_withLAI', 'JULES_GL9_withLAI_VPDl',
#        'model_JULES_test', 'JULES_test_VPDl', 'model_MATSIRO', 'MATSIRO_VPDl',
#        'model_MuSICA', 'MuSICA_VPDl', 'model_NASAEnt', 'NASAEnt_VPDl',
#        'model_NoahMPv401', 'NoahMPv401_VPDl', 'model_ORC2_r6593',
#        'ORC2_r6593_VPDl', 'model_ORC2_r6593_CO2', 'ORC2_r6593_CO2_VPDl',
#        'model_ORC3_r7245_NEE', 'ORC3_r7245_NEE_VPDl', 'model_ORC3_r8120',
#        'ORC3_r8120_VPDl', 'model_QUINCY', 'QUINCY_VPDl', 'model_STEMMUS-SCOPE',
#        'STEMMUS-SCOPE_VPDl', 'obs', 'obs_VPDl'],
#       dtype='object')

# %%
for site_name in site_names:

    site_mask  = (var_input['site_name'] == site_name)

    for model_in in model_names:

        print('site ', site_name, 'model', model_in)
        # print('Data is ', var_input.loc[site_mask])
        
        if model_in == 'obs':
            header = ''
        else:
            header = 'model_'

        file_input = f'{PLUMBER2_script}/txt/process1_output/Gs/Gs_{site_name}_{model_in}.csv'

        if os.path.exists(file_input):

            gs_input  = pd.read_csv(file_input, na_values=[''], usecols=['Gs','VPDl'])
            # if filter:
            #     Gs_tmp   = gs_input['Gs'][:]
            #     VPDl_tmp = gs_input['VPDl'][:]
            #     gs_input['Gs'], gs_input['VPDl'] = filter_gs(Gs_tmp, VPDl_tmp)
            
            print('len(var_input.loc[site_mask].values)', len(var_input.loc[site_mask,header+model_in].values),
                  "len(gs_input['Gs'].values)", len(gs_input['Gs'].values))
            
            # try:
            #     var_input.loc[site_mask, header+model_in] = gs_input['Gs'][:]
            #     var_input.loc[site_mask, model_in+'_VPDl']= gs_input['VPDl'][:]/1000. # Pa to kPa
            # except:
            #     var_input.loc[site_mask, header+model_in] = np.nan
            #     var_input.loc[site_mask, model_in+'_VPDl']= np.nan

#         else:
#             print('file_input',file_input,' does not exist')

#             var_input.loc[site_mask, header+model_in]  = np.nan
#             var_input.loc[site_mask, model_in+'_VPDl'] = np.nan

        gc.collect()

# var_input.to_csv(f'{PLUMBER2_script}/txt/process1_output/Gs_all_sites.csv')
# Out:
# site  AR-SLu model CABLE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5353
# site  AR-SLu model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 4954
# site  AR-SLu model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 6447
# site  AR-SLu model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5692
# site  AR-SLu model CLM5a
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5181
# site  AR-SLu model GFDL
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 4943
# site  AR-SLu model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5315
# site  AR-SLu model JULES_test
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5050
# site  AR-SLu model MATSIRO
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 4916
# site  AR-SLu model MuSICA
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5201
# site  AR-SLu model NASAEnt
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5523
# site  AR-SLu model NoahMPv401
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 5502
# site  AR-SLu model ORC2_r6593
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 6024
# site  AR-SLu model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 6039
# site  AR-SLu model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 6043
# site  AR-SLu model ORC3_r8120
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 6050
# site  AR-SLu model QUINCY
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 6365
# site  AR-SLu model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 6331
# site  AR-SLu model obs
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 4709
# site  AT-Neu model CABLE
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 100139
# site  AT-Neu model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 109618
# site  AT-Neu model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 57241
# site  AT-Neu model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 75395
# site  AT-Neu model CLM5a
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 77206
# site  AT-Neu model GFDL
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 73291
# site  AT-Neu model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 87177
# site  AT-Neu model JULES_test
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 90429
# site  AT-Neu model MATSIRO
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 98665
# site  AT-Neu model MuSICA
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 115878
# site  AT-Neu model NASAEnt
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 63390
# site  AT-Neu model NoahMPv401
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 87056
# site  AT-Neu model ORC2_r6593
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 91092
# site  AT-Neu model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 91178
# site  AT-Neu model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 91106
# site  AT-Neu model ORC3_r8120
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 88788
# site  AT-Neu model QUINCY
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 99602
# site  AT-Neu model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 116661
# site  AT-Neu model obs
# len(var_input.loc[site_mask].values) 192864 len(gs_input['Gs'].values) 105174
# site  AU-ASM model CABLE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 22957
# site  AU-ASM model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 21365
# site  AU-ASM model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 41631
# site  AU-ASM model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 34328
# site  AU-ASM model CLM5a
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 26806
# site  AU-ASM model GFDL
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 23408
# site  AU-ASM model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 36372
# site  AU-ASM model JULES_test
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 32211
# site  AU-ASM model MATSIRO
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 20955
# site  AU-ASM model MuSICA
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 21827
# site  AU-ASM model NASAEnt
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 22374
# site  AU-ASM model NoahMPv401
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 21760
# site  AU-ASM model ORC2_r6593
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 35289
# site  AU-ASM model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 36013
# site  AU-ASM model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 28167
# site  AU-ASM model ORC3_r8120
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 28066
# site  AU-ASM model QUINCY
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 22452
# site  AU-ASM model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 21861
# site  AU-ASM model obs
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 16718
# site  AU-Cow model CABLE
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 63344
# site  AU-Cow model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 63185
# site  AU-Cow model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 48145
# site  AU-Cow model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 58456
# site  AU-Cow model CLM5a
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 60251
# site  AU-Cow model GFDL
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 53666
# site  AU-Cow model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 62132
# site  AU-Cow model JULES_test
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 62832
# site  AU-Cow model MATSIRO
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 62182
# site  AU-Cow model MuSICA
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 47597
# site  AU-Cow model NASAEnt
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 50877
# site  AU-Cow model NoahMPv401
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 61405
# site  AU-Cow model ORC2_r6593
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 65439
# site  AU-Cow model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 65596
# site  AU-Cow model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 65062
# site  AU-Cow model ORC3_r8120
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 65064
# site  AU-Cow model QUINCY
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 58179
# site  AU-Cow model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 63359
# site  AU-Cow model obs
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 54161
# site  AU-Cpr model CABLE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 43836
# site  AU-Cpr model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 39366
# site  AU-Cpr model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 40216
# site  AU-Cpr model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 45195
# site  AU-Cpr model CLM5a
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 39239
# site  AU-Cpr model GFDL
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 41425
# site  AU-Cpr model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 46473
# site  AU-Cpr model JULES_test
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 43508
# site  AU-Cpr model MATSIRO
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 35739
# site  AU-Cpr model MuSICA
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 38722
# site  AU-Cpr model NASAEnt
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 30903
# site  AU-Cpr model NoahMPv401
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 43676
# site  AU-Cpr model ORC2_r6593
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 46476
# site  AU-Cpr model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 46638
# site  AU-Cpr model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 46617
# site  AU-Cpr model ORC3_r8120
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 46356
# site  AU-Cpr model QUINCY
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 45306
# site  AU-Cpr model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 44446
# site  AU-Cpr model obs
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 29350
# site  AU-Ctr model CABLE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 74859
# site  AU-Ctr model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 75310
# site  AU-Ctr model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 69895
# site  AU-Ctr model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 75456
# site  AU-Ctr model CLM5a
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 76429
# site  AU-Ctr model GFDL
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 83432
# site  AU-Ctr model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 75402
# site  AU-Ctr model JULES_test
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 77471
# site  AU-Ctr model MATSIRO
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 78527
# site  AU-Ctr model MuSICA
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 64498
# site  AU-Ctr model NASAEnt
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 65053
# site  AU-Ctr model NoahMPv401
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 76437
# site  AU-Ctr model ORC2_r6593
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 86708
# site  AU-Ctr model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 87324
# site  AU-Ctr model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 85818
# site  AU-Ctr model ORC3_r8120
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 85817
# site  AU-Ctr model QUINCY
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 71419
# site  AU-Ctr model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 76968
# site  AU-Ctr model obs
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 69389
# site  AU-Cum model CABLE
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 54049
# site  AU-Cum model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 51826
# site  AU-Cum model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 35599
# site  AU-Cum model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 49910
# site  AU-Cum model CLM5a
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 51437
# site  AU-Cum model GFDL
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 43772
# site  AU-Cum model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 53480
# site  AU-Cum model JULES_test
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 55580
# site  AU-Cum model MATSIRO
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 52238
# site  AU-Cum model MuSICA
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 45963
# site  AU-Cum model NASAEnt
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 46352
# site  AU-Cum model NoahMPv401
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 54057
# site  AU-Cum model ORC2_r6593
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 56169
# site  AU-Cum model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 56210
# site  AU-Cum model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 60216
# site  AU-Cum model ORC3_r8120
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 60191
# site  AU-Cum model QUINCY
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 52793
# site  AU-Cum model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 55052
# site  AU-Cum model obs
# len(var_input.loc[site_mask].values) 105168 len(gs_input['Gs'].values) 44408
# site  AU-DaP model CABLE
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 27678
# site  AU-DaP model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 19188
# site  AU-DaP model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 18497
# site  AU-DaP model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 29950
# site  AU-DaP model CLM5a
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 22158
# site  AU-DaP model GFDL
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 30711
# site  AU-DaP model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 31135
# site  AU-DaP model JULES_test
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 30687
# site  AU-DaP model MATSIRO
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 25040
# site  AU-DaP model MuSICA
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 23599
# site  AU-DaP model NASAEnt
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 23929
# site  AU-DaP model NoahMPv401
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 25864
# site  AU-DaP model ORC2_r6593
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 35090
# site  AU-DaP model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 35037
# site  AU-DaP model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 34477
# site  AU-DaP model ORC3_r8120
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 34168
# site  AU-DaP model QUINCY
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 27821
# site  AU-DaP model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 29098
# site  AU-DaP model obs
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 21816
# site  AU-DaS model CABLE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 38250
# site  AU-DaS model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 33880
# site  AU-DaS model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 31914
# site  AU-DaS model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 39479
# site  AU-DaS model CLM5a
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 37620
# site  AU-DaS model GFDL
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 46211
# site  AU-DaS model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 54778
# site  AU-DaS model JULES_test
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 52623
# site  AU-DaS model MATSIRO
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 33822
# site  AU-DaS model MuSICA
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 36982
# site  AU-DaS model NASAEnt
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 24689
# site  AU-DaS model NoahMPv401
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 36910
# site  AU-DaS model ORC2_r6593
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 52699
# site  AU-DaS model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 53270
# site  AU-DaS model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 52636
# site  AU-DaS model ORC3_r8120
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 52636
# site  AU-DaS model QUINCY
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 38450
# site  AU-DaS model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 40853
# site  AU-DaS model obs
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 31379
# site  AU-Dry model CABLE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 19688
# site  AU-Dry model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 16714
# site  AU-Dry model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 16880
# site  AU-Dry model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 23563
# site  AU-Dry model CLM5a
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 20704
# site  AU-Dry model GFDL
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 28711
# site  AU-Dry model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 33539
# site  AU-Dry model JULES_test
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 33089
# site  AU-Dry model MATSIRO
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 16551
# site  AU-Dry model MuSICA
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 19143
# site  AU-Dry model NASAEnt
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 16250
# site  AU-Dry model NoahMPv401
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 19293
# site  AU-Dry model ORC2_r6593
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 30510
# site  AU-Dry model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 30546
# site  AU-Dry model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 32413
# site  AU-Dry model ORC3_r8120
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 32422
# site  AU-Dry model QUINCY
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 20305
# site  AU-Dry model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 20295
# site  AU-Dry model obs
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 16983
# site  AU-Emr model CABLE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12550
# site  AU-Emr model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 11436
# site  AU-Emr model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9377
# site  AU-Emr model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12594
# site  AU-Emr model CLM5a
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12157
# site  AU-Emr model GFDL
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12226
# site  AU-Emr model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12554
# site  AU-Emr model JULES_test
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12597
# site  AU-Emr model MATSIRO
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9735
# site  AU-Emr model MuSICA
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 11943
# site  AU-Emr model NASAEnt
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 10851
# site  AU-Emr model NoahMPv401
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12436
# site  AU-Emr model ORC2_r6593
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12399
# site  AU-Emr model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12417
# site  AU-Emr model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12691
# site  AU-Emr model ORC3_r8120
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12681
# site  AU-Emr model QUINCY
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 13126
# site  AU-Emr model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12887
# site  AU-Emr model obs
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9710
# site  AU-GWW model CABLE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 26942
# site  AU-GWW model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 26233
# site  AU-GWW model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 26606
# site  AU-GWW model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 27496
# site  AU-GWW model CLM5a
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 28788
# site  AU-GWW model GFDL
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 28240
# site  AU-GWW model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 27798
# site  AU-GWW model JULES_test
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 26068
# site  AU-GWW model MATSIRO
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 24748
# site  AU-GWW model MuSICA
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 24970
# site  AU-GWW model NASAEnt
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 21345
# site  AU-GWW model NoahMPv401
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 27702
# site  AU-GWW model ORC2_r6593
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 30691
# site  AU-GWW model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 30275
# site  AU-GWW model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 30170
# site  AU-GWW model ORC3_r8120
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 30164
# site  AU-GWW model QUINCY
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 27906
# site  AU-GWW model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 28445
# site  AU-GWW model obs
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 18626
# site  AU-Gin model CABLE
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 45211
# site  AU-Gin model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 38411
# site  AU-Gin model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 35858
# site  AU-Gin model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 44759
# site  AU-Gin model CLM5a
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 42989
# site  AU-Gin model GFDL
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 45914
# site  AU-Gin model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 46800
# site  AU-Gin model JULES_test
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 45861
# site  AU-Gin model MATSIRO
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 39189
# site  AU-Gin model MuSICA
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 40090
# site  AU-Gin model NASAEnt
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 40637
# site  AU-Gin model NoahMPv401
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 43268
# site  AU-Gin model ORC2_r6593
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 47845
# site  AU-Gin model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 48013
# site  AU-Gin model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 47776
# site  AU-Gin model ORC3_r8120
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 47773
# site  AU-Gin model QUINCY
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 43465
# site  AU-Gin model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 45397
# site  AU-Gin model obs
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 33282
# site  AU-How model CABLE
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 79625
# site  AU-How model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 74623
# site  AU-How model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 74505
# site  AU-How model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 72080
# site  AU-How model CLM5a
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 86246
# site  AU-How model GFDL
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 84506
# site  AU-How model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 87668
# site  AU-How model JULES_test
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 95163
# site  AU-How model MATSIRO
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 75804
# site  AU-How model MuSICA
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 81680
# site  AU-How model NASAEnt
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 53959
# site  AU-How model NoahMPv401
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 75314
# site  AU-How model ORC2_r6593
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 103268
# site  AU-How model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 103667
# site  AU-How model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 101395
# site  AU-How model ORC3_r8120
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 101395
# site  AU-How model QUINCY
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 89103
# site  AU-How model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 97930
# site  AU-How model obs
# len(var_input.loc[site_mask].values) 262992 len(gs_input['Gs'].values) 71357
# site  AU-Lit model CABLE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 6647
# site  AU-Lit model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9247
# site  AU-Lit model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 8458
# site  AU-Lit model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 3972
# site  AU-Lit model CLM5a
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 8834
# site  AU-Lit model GFDL
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 5342
# site  AU-Lit model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 6384
# site  AU-Lit model JULES_test
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 6261
# site  AU-Lit model MATSIRO
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 6531
# site  AU-Lit model MuSICA
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 8886
# site  AU-Lit model NASAEnt
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 2988
# site  AU-Lit model NoahMPv401
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 7185
# site  AU-Lit model ORC2_r6593
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9594
# site  AU-Lit model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9701
# site  AU-Lit model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9403
# site  AU-Lit model ORC3_r8120
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9398
# site  AU-Lit model QUINCY
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 8100
# site  AU-Lit model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 12438
# site  AU-Lit model obs
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 9674
# site  AU-Otw model CABLE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10995
# site  AU-Otw model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10689
# site  AU-Otw model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 3292
# site  AU-Otw model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10568
# site  AU-Otw model CLM5a
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10195
# site  AU-Otw model GFDL
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10388
# site  AU-Otw model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10671
# site  AU-Otw model JULES_test
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10813
# site  AU-Otw model MATSIRO
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10828
# site  AU-Otw model MuSICA
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10353
# site  AU-Otw model NASAEnt
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 8448
# site  AU-Otw model NoahMPv401
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10966
# site  AU-Otw model ORC2_r6593
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10674
# site  AU-Otw model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10698
# site  AU-Otw model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10329
# site  AU-Otw model ORC3_r8120
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10331
# site  AU-Otw model QUINCY
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 10385
# site  AU-Otw model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 11330
# site  AU-Otw model obs
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 9785
# site  AU-Rig model CABLE
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 53466
# site  AU-Rig model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 48686
# site  AU-Rig model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 35120
# site  AU-Rig model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 55183
# site  AU-Rig model CLM5a
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 48913
# site  AU-Rig model GFDL
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 49712
# site  AU-Rig model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 53568
# site  AU-Rig model JULES_test
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 53261
# site  AU-Rig model MATSIRO
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 49284
# site  AU-Rig model MuSICA
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 50520
# site  AU-Rig model NASAEnt
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 42456
# site  AU-Rig model NoahMPv401
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 50070
# site  AU-Rig model ORC2_r6593
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 55743
# site  AU-Rig model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 55699
# site  AU-Rig model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 56194
# site  AU-Rig model ORC3_r8120
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 56154
# site  AU-Rig model QUINCY
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 52150
# site  AU-Rig model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 54924
# site  AU-Rig model obs
# len(var_input.loc[site_mask].values) 105216 len(gs_input['Gs'].values) 43890
# site  AU-Rob model CABLE
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 49596
# site  AU-Rob model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 49262
# site  AU-Rob model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 33094
# site  AU-Rob model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 39928
# site  AU-Rob model CLM5a
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 42209
# site  AU-Rob model GFDL
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 43073
# site  AU-Rob model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 47271
# site  AU-Rob model JULES_test
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 48408
# site  AU-Rob model MATSIRO
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 47464
# site  AU-Rob model MuSICA
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 37789
# site  AU-Rob model NASAEnt
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 42295
# site  AU-Rob model NoahMPv401
# len(var_input.loc[site_mask].values) 70128 len(gs_input['Gs'].values) 48250
# site  AU-Rob model ORC2_r6593
# site  AU-Rob model ORC2_r6593_CO2
# site  AU-Rob model ORC3_r7245_NEE
# site  AU-Rob model ORC3_r8120
# site  AU-Rob model QUINCY
# site  AU-Rob model STEMMUS-SCOPE
# site  AU-Rob model obs
# site  AU-Sam model CABLE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 65232
# site  AU-Sam model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 58997
# site  AU-Sam model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 43058
# site  AU-Sam model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 65520
# site  AU-Sam model CLM5a
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 64029
# site  AU-Sam model GFDL
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 64735
# site  AU-Sam model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 65531
# site  AU-Sam model JULES_test
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 66618
# site  AU-Sam model MATSIRO
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 65524
# site  AU-Sam model MuSICA
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 64354
# site  AU-Sam model NASAEnt
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 58879
# site  AU-Sam model NoahMPv401
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 64385
# site  AU-Sam model ORC2_r6593
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 65742
# site  AU-Sam model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 65795
# site  AU-Sam model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 66508
# site  AU-Sam model ORC3_r8120
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 66483
# site  AU-Sam model QUINCY
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 64857
# site  AU-Sam model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 67688
# site  AU-Sam model obs
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 48861
# site  AU-Stp model CABLE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 29298
# site  AU-Stp model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 21821
# site  AU-Stp model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 23838
# site  AU-Stp model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 36862
# site  AU-Stp model CLM5a
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 29127
# site  AU-Stp model GFDL
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 39044
# site  AU-Stp model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 45182
# site  AU-Stp model JULES_test
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 43972
# site  AU-Stp model MATSIRO
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 20312
# site  AU-Stp model MuSICA
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 27922
# site  AU-Stp model NASAEnt
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 21530
# site  AU-Stp model NoahMPv401
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 27825
# site  AU-Stp model ORC2_r6593
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 53429
# site  AU-Stp model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 53342
# site  AU-Stp model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 28673
# site  AU-Stp model ORC3_r8120
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 28673
# site  AU-Stp model QUINCY
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 32197
# site  AU-Stp model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 28744
# site  AU-Stp model obs
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 26280
# site  AU-TTE model CABLE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 14619
# site  AU-TTE model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 13220
# site  AU-TTE model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 29784
# site  AU-TTE model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 24496
# site  AU-TTE model CLM5a
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 16412
# site  AU-TTE model GFDL
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 15455
# site  AU-TTE model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 30922
# site  AU-TTE model JULES_test
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 31558
# site  AU-TTE model MATSIRO
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 13094
# site  AU-TTE model MuSICA
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 14587
# site  AU-TTE model NASAEnt
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 12551
# site  AU-TTE model NoahMPv401
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 14168
# site  AU-TTE model ORC2_r6593
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 17849
# site  AU-TTE model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 17847
# site  AU-TTE model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 17926
# site  AU-TTE model ORC3_r8120
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 17926
# site  AU-TTE model QUINCY
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 14819
# site  AU-TTE model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 14446
# site  AU-TTE model obs
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 12355
# site  AU-Tum model CABLE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 94674
# site  AU-Tum model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 95764
# site  AU-Tum model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 75893
# site  AU-Tum model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 68853
# site  AU-Tum model CLM5a
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 87223
# site  AU-Tum model GFDL
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 70435
# site  AU-Tum model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 80953
# site  AU-Tum model JULES_test
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 77647
# site  AU-Tum model MATSIRO
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 97377
# site  AU-Tum model MuSICA
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 81000
# site  AU-Tum model NASAEnt
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 72779
# site  AU-Tum model NoahMPv401
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 89010
# site  AU-Tum model ORC2_r6593
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 83896
# site  AU-Tum model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 83998
# site  AU-Tum model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 84023
# site  AU-Tum model ORC3_r8120
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 84069
# site  AU-Tum model QUINCY
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 89048
# site  AU-Tum model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 98462
# site  AU-Tum model obs
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 83999
# site  AU-Whr model CABLE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18465
# site  AU-Whr model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 16818
# site  AU-Whr model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 15499
# site  AU-Whr model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 16586
# site  AU-Whr model CLM5a
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 16778
# site  AU-Whr model GFDL
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 17692
# site  AU-Whr model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18196
# site  AU-Whr model JULES_test
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 17228
# site  AU-Whr model MATSIRO
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 16283
# site  AU-Whr model MuSICA
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 15011
# site  AU-Whr model NASAEnt
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 15502
# site  AU-Whr model NoahMPv401
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18146
# site  AU-Whr model ORC2_r6593
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18501
# site  AU-Whr model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18496
# site  AU-Whr model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18632
# site  AU-Whr model ORC3_r8120
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18636
# site  AU-Whr model QUINCY
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18148
# site  AU-Whr model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 18501
# site  AU-Whr model obs
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 14924
# site  AU-Wrr model CABLE
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29691
# site  AU-Wrr model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29747
# site  AU-Wrr model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 21841
# site  AU-Wrr model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 28171
# site  AU-Wrr model CLM5a
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29042
# site  AU-Wrr model GFDL
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 25468
# site  AU-Wrr model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29320
# site  AU-Wrr model JULES_test
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29268
# site  AU-Wrr model MATSIRO
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29419
# site  AU-Wrr model MuSICA
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 23589
# site  AU-Wrr model NASAEnt
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29090
# site  AU-Wrr model NoahMPv401
# len(var_input.loc[site_mask].values) 35088 len(gs_input['Gs'].values) 29325
# site  AU-Wrr model ORC2_r6593
# site  AU-Wrr model ORC2_r6593_CO2
# site  AU-Wrr model ORC3_r7245_NEE
# site  AU-Wrr model ORC3_r8120
# site  AU-Wrr model QUINCY
# site  AU-Wrr model STEMMUS-SCOPE
# site  AU-Wrr model obs
# site  AU-Ync model CABLE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 22511
# site  AU-Ync model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 20000
# site  AU-Ync model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 22816
# site  AU-Ync model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 36697
# site  AU-Ync model CLM5a
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 26699
# site  AU-Ync model GFDL
# ...
# site  US-Tw4 model NoahMPv401
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 7635
# site  US-Tw4 model ORC2_r6593
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 9310
# site  US-Tw4 model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 9298
# site  US-Tw4 model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 9177
# site  US-Tw4 model ORC3_r8120
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 9181
# site  US-Tw4 model QUINCY
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 8806
# site  US-Tw4 model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 9160
# site  US-Tw4 model obs
# len(var_input.loc[site_mask].values) 17520 len(gs_input['Gs'].values) 8578
# site  US-Twt model CABLE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 45199
# site  US-Twt model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 34704
# site  US-Twt model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 39891
# site  US-Twt model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 43163
# site  US-Twt model CLM5a
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 45722
# site  US-Twt model GFDL
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 43172
# site  US-Twt model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 43888
# site  US-Twt model JULES_test
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 41008
# site  US-Twt model MATSIRO
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 38708
# site  US-Twt model MuSICA
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 43611
# site  US-Twt model NASAEnt
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 37500
# site  US-Twt model NoahMPv401
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 36136
# site  US-Twt model ORC2_r6593
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 49240
# site  US-Twt model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 49309
# site  US-Twt model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 47692
# site  US-Twt model ORC3_r8120
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 47539
# site  US-Twt model QUINCY
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 47258
# site  US-Twt model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 47175
# site  US-Twt model obs
# len(var_input.loc[site_mask].values) 87648 len(gs_input['Gs'].values) 43828
# site  US-UMB model CABLE
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 95909
# site  US-UMB model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 96423
# site  US-UMB model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 83310
# site  US-UMB model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 79055
# site  US-UMB model CLM5a
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 90247
# site  US-UMB model GFDL
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 66386
# site  US-UMB model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 93355
# site  US-UMB model JULES_test
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 90748
# site  US-UMB model MATSIRO
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 94013
# site  US-UMB model MuSICA
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 77810
# site  US-UMB model NASAEnt
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 76673
# site  US-UMB model NoahMPv401
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 92546
# site  US-UMB model ORC2_r6593
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 87895
# site  US-UMB model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 87945
# site  US-UMB model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 88201
# site  US-UMB model ORC3_r8120
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 88471
# site  US-UMB model QUINCY
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 97184
# site  US-UMB model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 98912
# site  US-UMB model obs
# len(var_input.loc[site_mask].values) 131496 len(gs_input['Gs'].values) 69957
# site  US-Var model CABLE
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 116267
# site  US-Var model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 98214
# site  US-Var model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 86384
# site  US-Var model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 112160
# site  US-Var model CLM5a
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 96008
# site  US-Var model GFDL
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 97269
# site  US-Var model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 125084
# site  US-Var model JULES_test
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 122529
# site  US-Var model MATSIRO
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 108566
# site  US-Var model MuSICA
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 112834
# site  US-Var model NASAEnt
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 79798
# site  US-Var model NoahMPv401
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 106956
# site  US-Var model ORC2_r6593
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 136892
# site  US-Var model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 136934
# site  US-Var model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 136470
# site  US-Var model ORC3_r8120
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 135089
# site  US-Var model QUINCY
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 115347
# site  US-Var model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 116999
# site  US-Var model obs
# len(var_input.loc[site_mask].values) 245424 len(gs_input['Gs'].values) 81434
# site  US-WCr model CABLE
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 112412
# site  US-WCr model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 110690
# site  US-WCr model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 103703
# site  US-WCr model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 77702
# site  US-WCr model CLM5a
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 93174
# site  US-WCr model GFDL
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 99596
# site  US-WCr model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 108120
# site  US-WCr model JULES_test
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 99554
# site  US-WCr model MATSIRO
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 90436
# site  US-WCr model MuSICA
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 102597
# site  US-WCr model NASAEnt
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 92393
# site  US-WCr model NoahMPv401
# len(var_input.loc[site_mask].values) 140256 len(gs_input['Gs'].values) 95084
# site  US-WCr model ORC2_r6593
# site  US-WCr model ORC2_r6593_CO2
# site  US-WCr model ORC3_r7245_NEE
# site  US-WCr model ORC3_r8120
# site  US-WCr model QUINCY
# site  US-WCr model STEMMUS-SCOPE
# site  US-WCr model obs
# site  US-Whs model CABLE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 33373
# site  US-Whs model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 31146
# site  US-Whs model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 47483
# site  US-Whs model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 35143
# site  US-Whs model CLM5a
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 35307
# site  US-Whs model GFDL
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 38791
# site  US-Whs model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 44843
# site  US-Whs model JULES_test
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 47193
# site  US-Whs model MATSIRO
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 29240
# site  US-Whs model MuSICA
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 32984
# site  US-Whs model NASAEnt
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 29678
# site  US-Whs model NoahMPv401
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 33777
# site  US-Whs model ORC2_r6593
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 45183
# site  US-Whs model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 45139
# site  US-Whs model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 38797
# site  US-Whs model ORC3_r8120
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 38720
# site  US-Whs model QUINCY
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 39225
# site  US-Whs model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 33743
# site  US-Whs model obs
# len(var_input.loc[site_mask].values) 122736 len(gs_input['Gs'].values) 25361
# site  US-Wkg model CABLE
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 43110
# site  US-Wkg model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 40695
# site  US-Wkg model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 77384
# site  US-Wkg model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 64903
# site  US-Wkg model CLM5a
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 47717
# site  US-Wkg model GFDL
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 53769
# site  US-Wkg model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 57744
# site  US-Wkg model JULES_test
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 56819
# site  US-Wkg model MATSIRO
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 40084
# site  US-Wkg model MuSICA
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 44455
# site  US-Wkg model NASAEnt
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 40025
# site  US-Wkg model NoahMPv401
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 43389
# site  US-Wkg model ORC2_r6593
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 69531
# site  US-Wkg model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 69446
# site  US-Wkg model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 70270
# site  US-Wkg model ORC3_r8120
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 70390
# site  US-Wkg model QUINCY
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 46524
# site  US-Wkg model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 45631
# site  US-Wkg model obs
# len(var_input.loc[site_mask].values) 175296 len(gs_input['Gs'].values) 38810
# site  ZA-Kru model CABLE
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 24974
# site  ZA-Kru model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 21482
# site  ZA-Kru model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 20373
# site  ZA-Kru model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 24107
# site  ZA-Kru model CLM5a
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 22933
# site  ZA-Kru model GFDL
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 23718
# site  ZA-Kru model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 24933
# site  ZA-Kru model JULES_test
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 22212
# site  ZA-Kru model MATSIRO
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 20086
# site  ZA-Kru model MuSICA
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 24009
# site  ZA-Kru model NASAEnt
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 22178
# site  ZA-Kru model NoahMPv401
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 24811
# site  ZA-Kru model ORC2_r6593
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 26393
# site  ZA-Kru model ORC2_r6593_CO2
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 26339
# site  ZA-Kru model ORC3_r7245_NEE
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 26901
# site  ZA-Kru model ORC3_r8120
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 26894
# site  ZA-Kru model QUINCY
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 24923
# site  ZA-Kru model STEMMUS-SCOPE
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 25537
# site  ZA-Kru model obs
# len(var_input.loc[site_mask].values) 52608 len(gs_input['Gs'].values) 16688
# site  ZM-Mon model CABLE
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 6037
# site  ZM-Mon model CABLE-POP-CN
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 4387
# site  ZM-Mon model CHTESSEL_ERA5_3
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 5716
# site  ZM-Mon model CHTESSEL_Ref_exp1
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 5064
# site  ZM-Mon model CLM5a
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 5145
# site  ZM-Mon model GFDL
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 9555
# site  ZM-Mon model JULES_GL9_withLAI
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 7737
# site  ZM-Mon model JULES_test
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 8127
# site  ZM-Mon model MATSIRO
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 4737
# site  ZM-Mon model MuSICA
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 5141
# site  ZM-Mon model NASAEnt
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 3388
# site  ZM-Mon model NoahMPv401
# len(var_input.loc[site_mask].values) 17568 len(gs_input['Gs'].values) 4755
# site  ZM-Mon model ORC2_r6593
# site  ZM-Mon model ORC2_r6593_CO2
# site  ZM-Mon model ORC3_r7245_NEE
# site  ZM-Mon model ORC3_r8120
# site  ZM-Mon model QUINCY
# site  ZM-Mon model STEMMUS-SCOPE
# site  ZM-Mon model obs

# %%
for site_name in site_names:
    print(site_name)
    site_mask  = (var_input['site_name'] == site_name)
    print(np.sum(~np.isnan(var_input.loc[site_mask, 'model_CABLE'])))
# Out:
# AR-SLu
# 5353
# AT-Neu
# 82619
# AU-ASM
# 0
# AU-Cow
# 0
# AU-Cpr
# 0
# AU-Ctr
# 0
# AU-Cum
# 0
# AU-DaP
# 0
# AU-DaS
# 0
# AU-Dry
# 0
# AU-Emr
# 0
# AU-GWW
# 0
# AU-Gin
# 0
# AU-How
# 0
# AU-Lit
# 0
# AU-Otw
# 0
# AU-Rig
# 0
# AU-Rob
# 0
# AU-Sam
# 0
# AU-Stp
# 0
# AU-TTE
# 0
# AU-Tum
# 0
# AU-Whr
# 0
# AU-Wrr
# 0
# AU-Ync
# 0
# BE-Bra
# 0
# BE-Lon
# 0
# BE-Vie
# 0
# BR-Sa3
# 0
# BW-Ma1
# 0
# CA-NS1
# 0
# CA-NS2
# 0
# CA-NS4
# 0
# CA-NS5
# 0
# CA-NS6
# 0
# CA-NS7
# 0
# CA-Qcu
# 0
# CA-Qfo
# 0
# CA-SF1
# 0
# CA-SF2
# 0
# CA-SF3
# 0
# CH-Cha
# 0
# CH-Dav
# 0
# CH-Fru
# 0
# CH-Oe1
# 0
# CN-Cha
# 0
# CN-Cng
# 0
# CN-Dan
# 0
# CN-Din
# 0
# CN-Du2
# 0
# CN-HaM
# 0
# CN-Qia
# 0
# CZ-wet
# 0
# DE-Bay
# 0
# DE-Geb
# 0
# DE-Gri
# 0
# DE-Hai
# 0
# DE-Kli
# 0
# DE-Meh
# 0
# DE-Obe
# 0
# DE-Seh
# 0
# DE-SfN
# 0
# DE-Tha
# 0
# DE-Wet
# 0
# DK-Fou
# 0
# DK-Lva
# 0
# DK-Ris
# 0
# DK-Sor
# 0
# DK-ZaH
# 0
# ES-ES1
# 0
# ES-ES2
# 0
# ES-LMa
# 0
# ES-LgS
# 0
# ES-VDA
# 0
# FI-Hyy
# 0
# FI-Kaa
# 0
# FI-Lom
# 0
# FI-Sod
# 0
# FR-Fon
# 0
# FR-Gri
# 0
# FR-Hes
# 0
# FR-LBr
# 0
# FR-Lq1
# 0
# FR-Lq2
# 0
# FR-Pue
# 0
# GF-Guy
# 0
# HU-Bug
# 0
# ID-Pag
# 0
# IE-Ca1
# 0
# IE-Dri
# 0
# IT-Amp
# 0
# IT-BCi
# 0
# IT-CA1
# 0
# IT-CA2
# 0
# IT-CA3
# 0
# IT-Col
# 0
# IT-Cpz
# 0
# IT-Isp
# 0
# IT-LMa
# 0
# IT-Lav
# 0
# IT-MBo
# 0
# IT-Mal
# 0
# IT-Noe
# 0
# IT-Non
# 0
# IT-PT1
# 0
# IT-Ren
# 0
# IT-Ro1
# 0
# IT-Ro2
# 0
# IT-SR2
# 0
# IT-SRo
# 0
# JP-SMF
# 0
# NL-Ca1
# 0
# NL-Hor
# 0
# NL-Loo
# 0
# PL-wet
# 0
# PT-Esp
# 0
# PT-Mi1
# 0
# PT-Mi2
# 0
# RU-Che
# 0
# RU-Fyo
# 0
# RU-Zot
# 0
# SD-Dem
# 0
# SE-Deg
# 0
# UK-Gri
# 0
# UK-Ham
# 0
# UK-PL3
# 0
# US-AR1
# 0
# US-AR2
# 0
# US-ARM
# 0
# US-Aud
# 0
# US-Bar
# 0
# US-Bkg
# 0
# US-Blo
# 0
# US-Bo1
# 0
# US-Cop
# 0
# US-FPe
# 0
# US-GLE
# 0
# US-Goo
# 0
# US-Ha1
# 0
# US-Ho1
# 0
# US-KS2
# 0
# US-Los
# 0
# US-MMS
# 0
# US-MOz
# 0
# US-Me2
# 0
# US-Me4
# 0
# US-Me6
# 0
# US-Myb
# 0
# US-NR1
# 0
# US-Ne1
# 0
# US-Ne2
# 0
# US-Ne3
# 0
# US-PFa
# 0
# US-Prr
# 0
# US-SP1
# 0
# US-SP2
# 0
# US-SP3
# 0
# US-SRG
# 0
# US-SRM
# 0
# US-Syv
# 0
# US-Ton
# 0
# US-Tw4
# 0
# US-Twt
# 0
# US-UMB
# 0
# US-Var
# 0
# US-WCr
# 0
# US-Whs
# 0
# US-Wkg
# 0
# ZA-Kru
# 0
# ZM-Mon
# 0
